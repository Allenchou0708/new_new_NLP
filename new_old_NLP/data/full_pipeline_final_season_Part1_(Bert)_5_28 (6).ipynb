# %% [markdown]
# # Baseline
# python: 3.8.*

# %% [markdown]
# Download our starter pack (3~5 min)

# %%
cd /content
# Out:
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
### 第一次跑要下載資料到Google Drive


# !git clone https://github.com/s109703023/NCKU-AICUP2023-baseline.git
# !cd /content/drive/MyDrive/NCKU-AICUP2023-baseline/
# !gdown --folder 1tdf_i6XNYT6jpOA6F_lqU4mRRh1xYPcl
# !mv baseline/* ./

# %%
pwd
# Out:
# '/content'

# %%
cd /content/drive/MyDrive/沈倢妤/testt/NCKU-AICUP2023-baseline
# Out:
# /content/drive/MyDrive/沈倢妤/testt/NCKU-AICUP2023-baseline

# %%
ls
# Out:
# checkpoints/     full_pipeline_for_roberta_ipynb_5_21.ipynb  README.md
# data/            full_pipeline.ipynb                         requirements.txt
# dataset.py       logs/                                       utils.py
# distinguish.csv  __pycache__/

# %%
### 確定資料夾在NCKU、裡面有/data這樣

### 直接寫ls 才會藍藍的 (?)

# %%
pwd
# Out:
# '/content/drive/MyDrive/沈倢妤/testt/NCKU-AICUP2023-baseline'

# %%
ls data
# Out:
# dev_doc5sent5.jsonl         public_train.jsonl      train_doc5.jsonl
# dev_doc5sent5.pkl           test_doc5.jsonl         train_doc5sent5.jsonl
# hanlp_con_results.pkl       test_doc5sent5.jsonl    train_doc5sent5.pkl
# hanlp_con_test_results.pkl  test_doc5sent5.pkl      wiki-pages/
# public_test.jsonl           train_doc5_data1.jsonl

# %%
# %pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Collecting ipywidgets==8.0.5 (from -r requirements.txt (line 3))
#   Using cached ipywidgets-8.0.5-py3-none-any.whl (138 kB)
# Collecting pandarallel==1.6.4 (from -r requirements.txt (line 4))
#   Using cached pandarallel-1.6.4.tar.gz (12 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas==1.5.3 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 5)) (1.5.3)
# Requirement already satisfied: scikit-learn==1.2.2 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 6)) (1.2.2)
# Collecting tensorboard==2.11.0 (from -r requirements.txt (line 7))
#   Using cached tensorboard-2.11.0-py3-none-any.whl (6.0 MB)
# Collecting torch==1.13.1+cu116 (from -r requirements.txt (line 8))
#   Using cached https://download.pytorch.org/whl/cu116/torch-1.13.1%2Bcu116-cp310-cp310-linux_x86_64.whl (1977.9 MB)
# Requirement already satisfied: tqdm==4.65.0 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 9)) (4.65.0)
# Collecting opencc (from -r requirements.txt (line 10))
#   Downloading OpenCC-1.1.6-cp310-cp310-manylinux1_x86_64.whl (778 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 778.3/778.3 kB 51.5 MB/s eta 0:00:00
# Collecting hanlp (from -r requirements.txt (line 11))
#   Downloading hanlp-2.1.0b50-py3-none-any.whl (651 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 651.1/651.1 kB 67.9 MB/s eta 0:00:00
# Collecting transformers==4.27.1 (from -r requirements.txt (line 12))
#   Downloading transformers-4.27.1-py3-none-any.whl (6.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 124.9 MB/s eta 0:00:00
# Collecting wikipedia==1.4.0 (from -r requirements.txt (line 13))
#   Downloading wikipedia-1.4.0.tar.gz (27 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: ipython>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets==8.0.5->-r requirements.txt (line 3)) (7.34.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets==8.0.5->-r requirements.txt (line 3)) (5.7.1)
# Collecting widgetsnbextension~=4.0 (from ipywidgets==8.0.5->-r requirements.txt (line 3))
#   Downloading widgetsnbextension-4.0.7-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 98.9 MB/s eta 0:00:00
# Requirement already satisfied: jupyterlab-widgets~=3.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets==8.0.5->-r requirements.txt (line 3)) (3.0.7)
# Collecting dill>=0.3.1 (from pandarallel==1.6.4->-r requirements.txt (line 4))
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 16.5 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from pandarallel==1.6.4->-r requirements.txt (line 4)) (5.9.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas==1.5.3->-r requirements.txt (line 5)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas==1.5.3->-r requirements.txt (line 5)) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas==1.5.3->-r requirements.txt (line 5)) (1.22.4)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.2.2->-r requirements.txt (line 6)) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.2.2->-r requirements.txt (line 6)) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.2.2->-r requirements.txt (line 6)) (3.1.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.11.0->-r requirements.txt (line 7)) (1.4.0)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.11.0->-r requirements.txt (line 7)) (1.54.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.11.0->-r requirements.txt (line 7)) (2.17.3)
# Collecting google-auth-oauthlib<0.5,>=0.4.1 (from tensorboard==2.11.0->-r requirements.txt (line 7))
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.11.0->-r requirements.txt (line 7)) (3.4.3)
# Requirement already satisfied: protobuf<4,>=3.9.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.11.0->-r requirements.txt (line 7)) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.11.0->-r requirements.txt (line 7)) (2.27.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.11.0->-r requirements.txt (line 7)) (67.7.2)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0 (from tensorboard==2.11.0->-r requirements.txt (line 7))
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 113.3 MB/s eta 0:00:00
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.11.0->-r requirements.txt (line 7)) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.11.0->-r requirements.txt (line 7)) (2.3.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.11.0->-r requirements.txt (line 7)) (0.40.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==1.13.1+cu116->-r requirements.txt (line 8)) (4.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.27.1->-r requirements.txt (line 12)) (3.12.0)
# Collecting huggingface-hub<1.0,>=0.11.0 (from transformers==4.27.1->-r requirements.txt (line 12))
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 26.3 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.27.1->-r requirements.txt (line 12)) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.27.1->-r requirements.txt (line 12)) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.27.1->-r requirements.txt (line 12)) (2022.10.31)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers==4.27.1->-r requirements.txt (line 12))
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 120.0 MB/s eta 0:00:00
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from wikipedia==1.4.0->-r requirements.txt (line 13)) (4.11.2)
# Collecting hanlp-common>=0.0.19 (from hanlp->-r requirements.txt (line 11))
#   Downloading hanlp_common-0.0.19.tar.gz (28 kB)
#   Preparing metadata (setup.py) ... done
# Collecting hanlp-downloader (from hanlp->-r requirements.txt (line 11))
#   Downloading hanlp_downloader-0.0.25.tar.gz (13 kB)
#   Preparing metadata (setup.py) ... done
# Collecting hanlp-trie>=0.0.4 (from hanlp->-r requirements.txt (line 11))
#   Downloading hanlp_trie-0.0.5.tar.gz (6.7 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pynvml (from hanlp->-r requirements.txt (line 11))
#   Downloading pynvml-11.5.0-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 8.9 MB/s eta 0:00:00
# Collecting sentencepiece>=0.1.91 (from hanlp->-r requirements.txt (line 11))
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 86.3 MB/s eta 0:00:00
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from hanlp->-r requirements.txt (line 11)) (2.3.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers==4.27.1->-r requirements.txt (line 12))
#   Downloading tokenizers-0.11.6-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 119.9 MB/s eta 0:00:00
# Collecting toposort==1.5 (from hanlp->-r requirements.txt (line 11))
#   Downloading toposort-1.5-py2.py3-none-any.whl (7.6 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard==2.11.0->-r requirements.txt (line 7)) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard==2.11.0->-r requirements.txt (line 7)) (0.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard==2.11.0->-r requirements.txt (line 7)) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard==2.11.0->-r requirements.txt (line 7)) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard==2.11.0->-r requirements.txt (line 7)) (1.3.1)
# Collecting phrasetree (from hanlp-common>=0.0.19->hanlp->-r requirements.txt (line 11))
#   Downloading phrasetree-0.0.8.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 6.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers==4.27.1->-r requirements.txt (line 12)) (2023.4.0)
# Collecting jedi>=0.16 (from ipython>=6.1.0->ipywidgets==8.0.5->-r requirements.txt (line 3))
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 101.6 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets==8.0.5->-r requirements.txt (line 3)) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets==8.0.5->-r requirements.txt (line 3)) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets==8.0.5->-r requirements.txt (line 3)) (3.0.38)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets==8.0.5->-r requirements.txt (line 3)) (2.14.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets==8.0.5->-r requirements.txt (line 3)) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets==8.0.5->-r requirements.txt (line 3)) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets==8.0.5->-r requirements.txt (line 3)) (4.8.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard==2.11.0->-r requirements.txt (line 7)) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard==2.11.0->-r requirements.txt (line 7)) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard==2.11.0->-r requirements.txt (line 7)) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard==2.11.0->-r requirements.txt (line 7)) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard==2.11.0->-r requirements.txt (line 7)) (2.1.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->wikipedia==1.4.0->-r requirements.txt (line 13)) (2.4.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets==8.0.5->-r requirements.txt (line 3)) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets==8.0.5->-r requirements.txt (line 3)) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=6.1.0->ipywidgets==8.0.5->-r requirements.txt (line 3)) (0.2.6)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard==2.11.0->-r requirements.txt (line 7)) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard==2.11.0->-r requirements.txt (line 7)) (3.2.2)
# Building wheels for collected packages: pandarallel, wikipedia, hanlp-common, hanlp-trie, hanlp-downloader, phrasetree
#   Building wheel for pandarallel (setup.py) ... done
#   Created wheel for pandarallel: filename=pandarallel-1.6.4-py3-none-any.whl size=16663 sha256=5dc15072020355a38ef47fdc402c575fddf9e0ac2cab2ac3d9ba3029b8c824b4
#   Stored in directory: /root/.cache/pip/wheels/80/3a/18/ad02ff58953d0aea45e4f30682a40974b336626a50fe4a2f90
#   Building wheel for wikipedia (setup.py) ... done
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11680 sha256=292f3827a763316b1506f4d9968b37320a52f0362ecd7e1ceaf0f098f17e9956
#   Stored in directory: /root/.cache/pip/wheels/5e/b6/c5/93f3dec388ae76edc830cb42901bb0232504dfc0df02fc50de
#   Building wheel for hanlp-common (setup.py) ... done
#   Created wheel for hanlp-common: filename=hanlp_common-0.0.19-py3-none-any.whl size=30634 sha256=a2cf904a12f70a7e0c2e2f7d4753e2f2e4ebb799209d47995e14c10f58298fc5
#   Stored in directory: /root/.cache/pip/wheels/77/5f/9e/2e877efbb98d58173396c53aacfd89369b6cc173ed9f2c0390
#   Building wheel for hanlp-trie (setup.py) ... done
#   Created wheel for hanlp-trie: filename=hanlp_trie-0.0.5-py3-none-any.whl size=6816 sha256=aa6f76c0e503cbf858ff95960f9c9bbda73da812eeaf56bd24b0ab69317aae8e
#   Stored in directory: /root/.cache/pip/wheels/4b/ff/a9/6883d860cbed0247ce316c39757ff61c1f5bfd3556abfbefa0
#   Building wheel for hanlp-downloader (setup.py) ... done
#   Created wheel for hanlp-downloader: filename=hanlp_downloader-0.0.25-py3-none-any.whl size=13746 sha256=45e8a23ea0cbe9b4991efc1db42464d422c8c69f3596ae0df8b8d5b51c2425c2
#   Stored in directory: /root/.cache/pip/wheels/71/2b/67/65892ee65ea68b4c0936b9a8f2ea73665c3389fec08746b949
#   Building wheel for phrasetree (setup.py) ... done
#   Created wheel for phrasetree: filename=phrasetree-0.0.8-py3-none-any.whl size=44219 sha256=3b8999d6d72c8a1787778b8e65b6a705f73da22716d39d6f74300449ae9baf64
#   Stored in directory: /root/.cache/pip/wheels/dc/3f/2f/d995b1953a6598baf9d9119304f864c602018a15a7d59ad0ab
# Successfully built pandarallel wikipedia hanlp-common hanlp-trie hanlp-downloader phrasetree
# Installing collected packages: toposort, tokenizers, sentencepiece, phrasetree, opencc, widgetsnbextension, torch, tensorboard-data-server, pynvml, jedi, hanlp-common, dill, wikipedia, huggingface-hub, hanlp-trie, hanlp-downloader, transformers, pandarallel, ipywidgets, google-auth-oauthlib, tensorboard, hanlp
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.6.4
#     Uninstalling widgetsnbextension-3.6.4:
#       Successfully uninstalled widgetsnbextension-3.6.4
#   Attempting uninstall: torch
#     Found existing installation: torch 2.0.1+cu118
#     Uninstalling torch-2.0.1+cu118:
#       Successfully uninstalled torch-2.0.1+cu118
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.7.0
#     Uninstalling tensorboard-data-server-0.7.0:
#       Successfully uninstalled tensorboard-data-server-0.7.0
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.7.1
#     Uninstalling ipywidgets-7.7.1:
#       Successfully uninstalled ipywidgets-7.7.1
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 1.0.0
#     Uninstalling google-auth-oauthlib-1.0.0:
#       Successfully uninstalled google-auth-oauthlib-1.0.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.12.2
#     Uninstalling tensorboard-2.12.2:
#       Successfully uninstalled tensorboard-2.12.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.12.0 requires tensorboard<2.13,>=2.12, but you have tensorboard 2.11.0 which is incompatible.
# torchaudio 2.0.2+cu118 requires torch==2.0.1, but you have torch 1.13.1+cu116 which is incompatible.
# torchdata 0.6.1 requires torch==2.0.1, but you have torch 1.13.1+cu116 which is incompatible.
# torchtext 0.15.2 requires torch==2.0.1, but you have torch 1.13.1+cu116 which is incompatible.
# torchvision 0.15.2+cu118 requires torch==2.0.1, but you have torch 1.13.1+cu116 which is incompatible.
# Successfully installed dill-0.3.6 google-auth-oauthlib-0.4.6 hanlp-2.1.0b50 hanlp-common-0.0.19 hanlp-downloader-0.0.25 hanlp-trie-0.0.5 huggingface-hub-0.14.1 ipywidgets-8.0.5 jedi-0.18.2 opencc-1.1.6 pandarallel-1.6.4 phrasetree-0.0.8 pynvml-11.5.0 sentencepiece-0.1.99 tensorboard-2.11.0 tensorboard-data-server-0.6.1 tokenizers-0.11.6 toposort-1.5 torch-1.13.1+cu116 transformers-4.27.1 widgetsnbextension-4.0.7 wikipedia-1.4.0

# %% [markdown]
# notebook1
# ## PART 1. Document retrieval
# 難度：★★★★☆

# %% [markdown]
# ### Document retrieval 流程
# - Step 1: 使用 Constituency Parser 找出 claim 中的 Noun Phrases (NPs）
# - Step 2: 從 Wikipedia API 中取出和 NP 相符合的頁面名稱
# - Step 3: 保留出現在句子 index 最靠前的五篇文章作為相關文章

# %% [markdown]
# Prepare the environment and import all library we need

# %%
# built-in libs
import json
import pickle
import re
from dataclasses import dataclass
from pathlib import Path
from typing import Dict, List, Set, Tuple, Union

# 3rd party libs
import hanlp
import opencc
import pandas as pd
import wikipedia
from hanlp.components.pipeline import Pipeline
from pandarallel import pandarallel

# our own libs
from utils import load_json

pandarallel.initialize(progress_bar=True, verbose=0, nb_workers=10)
wikipedia.set_lang("zh")

# %% [markdown]
# Preload the data.

# %%
TRAIN_DATA = load_json("data/public_train.jsonl")
TEST_DATA = load_json("data/public_test.jsonl")
CONVERTER_T2S = opencc.OpenCC("t2s.json")
CONVERTER_S2T = opencc.OpenCC("s2t.json")

# %% [markdown]
# Data class for type hinting

# %%
@dataclass
class Claim:
    data: str

@dataclass
class AnnotationID:
    id: int

@dataclass
class EvidenceID:
    id: int

@dataclass
class PageTitle:
    title: str

@dataclass
class SentenceID:
    id: int

@dataclass
class Evidence:
    data: List[List[Tuple[AnnotationID, EvidenceID, PageTitle, SentenceID]]]

# %% [markdown]
# ### Helper function

# %% [markdown]
# For the sake of consistency, we convert traditional to simplified Chinese first before converting it back to traditional Chinese.  This is due to some errors occuring when converting traditional to traditional Chinese.

# %%
def do_st_corrections(text: str) -> str:
    simplified = CONVERTER_T2S.convert(text)

    return CONVERTER_S2T.convert(simplified)

# %% [markdown]
# We use constituency parsing to separate part of speeches or so called constituent to extract noun phrases.  In the later stages, we will use the noun phrases as the query to search for relevant documents.

# %% [markdown]
# ![con](https://www.baeldung.com/wp-content/uploads/sites/4/2020/06/constituency_parse_tree-1.png)

# %% [markdown]
# ##### 現在正在調這裡

# %%
def get_nps_hanlp(
    predictor: Pipeline,
    d: Dict[str, Union[int, Claim, Evidence]],
) -> List[str]:
    claim = d["claim"]
    tree = predictor(claim)["con"]
    nps = [
        do_st_corrections("".join(subtree.leaves()))
        for subtree in tree.subtrees(lambda t: t.label() == "NP")
    ]

    return nps

# %%
## add: 增加filter，刪除list中重複的元素（刪掉短的元素）
def filter_nps(nps:List[str])-> List[str]:
    n = len(nps)
    if n==0:
        return []
    result = [nps[0]]
    for s in nps:
        if s not in result[len(result)-1]:
            result.append(s)
    return result

# %%
import re
def filter_nps(nps:List[str], bound:int)-> List[str]:
    n = len(nps)
    if n==0:
        return []
    result = [nps[0]]
    for i in range(1,n):
        if len(nps[i])>=bound:
            result.append(nps[i])
        else:
            if any(nps[i] in s for s in result):
                continue
            result.append(re.sub(r'[^\w\s]', '', nps[i]))
    return result

# %%
## testt
list1 = ['天衛三軌道在天王星內部的磁層', '天衛三軌道', '天衛', '軌道', '天王星內部', '磁層', '《仲夏夜之夢》作者緹坦妮雅', '《仲夏夜之夢》作者', '《仲夏夜之夢》', '仲夏夜', '夢', '作者', '緹坦妮雅']
print(filter_nps(list1,5))
# Out:
# ['天衛三軌道在天王星內部的磁層', '天衛三軌道', '天王星內部', '《仲夏夜之夢》作者緹坦妮雅', '《仲夏夜之夢》作者', '《仲夏夜之夢》']

# %% [markdown]
# #### 評估 Document Retrieval
#
# \begin{align*}
# \textrm{Precision}&=\frac{\textrm{relevant} \cap \textrm{retrieved}}{\textrm{retrieved}} \\
# &=\frac{\textrm{抽取到的文章與正確文章的交集}}{\textrm{抽取到的文章}}
# \end{align*}
#
# \begin{align*}
# \textrm{Recall}&=\frac{\textrm{relevant} \cap \textrm{retrieved}}{\textrm{relevant}} \\
# &=\frac{\textrm{抽取到的文章與正確文章的交集}}{\textrm{正確文章}}
# \end{align*}
#
# <img src="https://i.imgur.com/1q3c6Zw.png" alt="example" width="60%">

# %%
def calculate_precision(
    data: List[Dict[str, Union[int, Claim, Evidence]]],
    predictions: pd.Series,
) -> None:
    precision = 0
    count = 0

    for i, d in enumerate(data):
        if d["label"] == "NOT ENOUGH INFO":
            continue

        # Extract all ground truth of titles of the wikipedia pages
        # evidence[2] refers to the title of the wikipedia page
        gt_pages = set([
            evidence[2]
            for evidence_set in d["evidence"]
            for evidence in evidence_set
        ])

        predicted_pages = predictions.iloc[i]
        hits = predicted_pages.intersection(gt_pages)
        if len(predicted_pages) != 0:
            precision += len(hits) / len(predicted_pages)

        count += 1

    # Macro precision
    print(f"Precision: {precision / count}")


def calculate_recall(
    data: List[Dict[str, Union[int, Claim, Evidence]]],
    predictions: pd.Series,
) -> None:
    recall = 0
    count = 0

    for i, d in enumerate(data):
        if d["label"] == "NOT ENOUGH INFO":
            continue

        gt_pages = set([
            evidence[2]
            for evidence_set in d["evidence"]
            for evidence in evidence_set
        ])
        predicted_pages = predictions.iloc[i]
        hits = predicted_pages.intersection(gt_pages)
        recall += len(hits) / len(gt_pages)
        count += 1

    print(f"Recall: {recall / count}")

# %% [markdown]
# The default amount of documents retrieved is at most five documents.  This `num_pred_doc` can be adjusted based on your objective.  Save data in jsonl format.

# %%
def save_doc(
    data: List[Dict[str, Union[int, Claim, Evidence]]],
    predictions: pd.Series,
    mode: str = "train",
    num_pred_doc: int = 5,
) -> None:
    with open(
        f"data/{mode}_doc{num_pred_doc}.jsonl",
        "w",
        encoding="utf8",
    ) as f:
        for i, d in enumerate(data):
            d["predicted_pages"] = list(predictions.iloc[i])
            f.write(json.dumps(d, ensure_ascii=False) + "\n")

# %% [markdown]
# ### Main function for document retrieval

# %%
def get_pred_pages(series_data: pd.Series) -> Set[Dict[int, str]]:
    results = []
    tmp_muji = []
    # wiki_page: its index showned in claim
    mapping = {}
    claim = series_data["claim"]
    nps = series_data["hanlp_results"]
    first_wiki_term = []

    for i, np in enumerate(nps):
        # Simplified Traditional Chinese Correction
        wiki_search_results = [
            do_st_corrections(w) for w in wikipedia.search(np)
        ]

        # Remove the wiki page's description in brackets
        wiki_set = [re.sub(r"\s\(\S+\)", "", w) for w in wiki_search_results]
        wiki_df = pd.DataFrame({
            "wiki_set": wiki_set,
            "wiki_results": wiki_search_results
        })

        # Elements in wiki_set --> index
        # Extracting only the first element is one way to avoid extracting
        # too many of the similar wiki pages
        grouped_df = wiki_df.groupby("wiki_set", sort=False).first()
        candidates = grouped_df["wiki_results"].tolist()
        # muji refers to wiki_set
        muji = grouped_df.index.tolist()

        for prefix, term in zip(muji, candidates):
            if prefix not in tmp_muji:
                matched = False

                # Take at least one term from the first noun phrase
                if i == 0:
                    first_wiki_term.append(term)

                # Walrus operator :=
                # https://docs.python.org/3/whatsnew/3.8.html#assignment-expressions
                # Through these filters, we are trying to figure out if the term
                # is within the claim
                if (((new_term := term) in claim) or
                    ((new_term := term.replace("·", "")) in claim) or
                    ((new_term := term.split(" ")[0]) in claim) or
                    ((new_term := term.replace("-", " ")) in claim)):
                    matched = True

                elif "·" in term:
                    splitted = term.split("·")
                    for split in splitted:
                        if (new_term := split) in claim:
                            matched = True
                            break

                if matched:
                    # post-processing
                    term = term.replace(" ", "_")
                    term = term.replace("-", "")
                    results.append(term)
                    mapping[term] = claim.find(new_term)
                    tmp_muji.append(new_term)

    # 7 is a hyperparameter
    par = 7
    if len(results) > par:
        assert -1 not in mapping.values()
        results = sorted(mapping, key=mapping.get)[:par]
    elif len(results) < 1:
        results = first_wiki_term

    return set(results)

# %% [markdown]
# #### Groupby pages
# - 如果有多個後綴類型的pages，只取第一個配對到的
# ![groupby](https://imgur.com/FRE4BVv.png)

# %% [markdown]
# ### Step 1. Get noun phrases from hanlp consituency parsing tree

# %% [markdown]
# Setup [HanLP](https://github.com/hankcs/HanLP) predictor (1 min)

# %%
predictor = (hanlp.pipeline().append(
    hanlp.load("FINE_ELECTRA_SMALL_ZH"),
    output_key="tok",
).append(
    hanlp.load("CTB9_CON_ELECTRA_SMALL"),
    output_key="con",
    input_key="tok",
))
# Out:
# Downloading https://file.hankcs.com/hanlp/tok/fine_electra_small_20220615_231803.zip to /root/.hanlp/tok/fine_electra_small_20220615_231803.zip
# 100%  43.5 MiB   2.7 MiB/s ETA:  0 s [=========================================]
# Decompressing /root/.hanlp/tok/fine_electra_small_20220615_231803.zip to /root/.hanlp/tok
# Downloading https://file.hankcs.com/hanlp/utils/char_table_20210602_202632.json.zip to /root/.hanlp/utils/char_table_20210602_202632.json.zip
# 100%  26.7 KiB  26.7 KiB/s ETA:  0 s [=========================================]
# Decompressing /root/.hanlp/utils/char_table_20210602_202632.json.zip to /root/.hanlp/utils
# Downloading https://file.hankcs.com/hanlp/transformers/electra_zh_small_20210706_125427.zip to /root/.hanlp/transformers/electra_zh_small_20210706_125427.zip
# 100%  41.2 KiB  41.2 KiB/s ETA:  0 s [=========================================]
# Decompressing /root/.hanlp/transformers/electra_zh_small_20210706_125427.zip to /root/.hanlp/transformers
# Downloading https://file.hankcs.com/hanlp/constituency/ctb9_con_electra_small_20220215_230116.zip to /root/.hanlp/constituency/ctb9_con_electra_small_20220215_230116.zip
# 100%  54.8 MiB  28.9 MiB/s ETA:  0 s [=========================================]
# Decompressing /root/.hanlp/constituency/ctb9_con_electra_small_20220215_230116.zip to /root/.hanlp/constituency

# %% [markdown]
# We will skip this process which for creating parsing tree when demo on class

# %% [markdown]
# ##### 刪

# %%
hanlp_file = f"data/hanlp_con_results.pkl"
if Path(hanlp_file).exists():
    with open(hanlp_file, "rb") as f:
        hanlp_results = pickle.load(f)
else:
    hanlp_results = [get_nps_hanlp(predictor, d) for d in TRAIN_DATA]
    # hanlp_results = [filter_nps(get_nps_hanlp(predictor, d),5) for d in TRAIN_DATA]
    with open(hanlp_file, "wb") as f:
        pickle.dump(hanlp_results, f)

# %% [markdown]
# Get pages via wiki online api

# %%
doc_path = f"data/train_doc5.jsonl"
if Path(doc_path).exists():
    with open(doc_path, "r", encoding="utf8") as f:
        predicted_results = pd.Series([
            set(json.loads(line)["predicted_pages"])
            for line in f
        ])
else:
    train_df = pd.DataFrame(TRAIN_DATA)
    train_df.loc[:, "hanlp_results"] = hanlp_results
    predicted_results = train_df.apply(get_pred_pages, axis=1)
    save_doc(TRAIN_DATA, predicted_results, mode="train")

# %%
## test
for d in TRAIN_DATA[:10]:
  print(get_nps_hanlp(predictor, d))
  print(filter_nps(get_nps_hanlp(predictor, d),5))
  print()
# Out:
# ['天衛三軌道在天王星內部的磁層', '天衛三軌道', '天衛', '軌道', '天王星內部', '磁層', '《仲夏夜之夢》作者緹坦妮雅', '《仲夏夜之夢》作者', '《仲夏夜之夢》', '仲夏夜', '夢', '作者', '緹坦妮雅']
# ['天衛三軌道在天王星內部的磁層', '天衛三軌道', '天王星內部', '《仲夏夜之夢》作者緹坦妮雅', '《仲夏夜之夢》作者', '《仲夏夜之夢》']
#
# ['信天翁科的活動範圍', '信天翁科', '活動範圍', '北冰洋以及南太平洋', '北冰洋', '南太平洋', '太平洋', '牠的翼展', '牠', '翼展', '世界上現存的翼展最大的鳥類', '世界', '翼展', '鳥類']
# ['信天翁科的活動範圍', '北冰洋以及南太平洋', '牠的翼展', '世界上現存的翼展最大的鳥類']
#
# ['F.I.R.的團員', 'F.I.R.', '團員', '主唱Faye飛（詹雯婷）、吉他手Real阿沁（黃漢青）、鍵盤手Ian（陳建寧）', '主唱Faye飛（詹雯婷）', '主唱', 'Faye飛（詹雯婷）', 'Faye飛', 'Faye', '詹雯婷', '吉他手Real阿沁（黃漢青）', '吉他手', '黃漢青', '鍵盤手Ian（陳建寧）', '鍵盤手', 'Ian（陳建寧）', '陳建寧', '亞洲樂壇不常見的一女二男三人組合樂團', '亞洲樂壇', '亞洲', '樂壇', '一女二男', '一女', '女', '二男', '男', '三人', '人', '組合樂團', '樂團']
# ['F.I.R.的團員', 'F.I.R.', '主唱Faye飛（詹雯婷）、吉他手Real阿沁（黃漢青）、鍵盤手Ian（陳建寧）', '主唱Faye飛（詹雯婷）', 'Faye飛（詹雯婷）', 'Faye飛', '吉他手Real阿沁（黃漢青）', '鍵盤手Ian（陳建寧）', 'Ian（陳建寧）', '亞洲樂壇不常見的一女二男三人組合樂團']
#
# ['香港國際機場', '24小時', '小時', '它', '2001年', '世界最佳機場', '世界', '機場', '全宇宙最佳機場', '全宇宙', '宇宙', '機場']
# ['香港國際機場', '24小時', '它', '2001年', '世界最佳機場', '全宇宙最佳機場']
#
# ['北理工', '歷史上最後一批副部級高校，黨委書記和校長列入中央管理的高校', '歷史', '副部級高校', '副部級', '部級', '高校', '黨委書記和校長', '中央管理', '高校', '中管高校', '“副部級高校”', '副部級', '部級', '高校', '中華人民共和國中央部屬高校中31所普通高等學校的統稱', '中華人民共和國中央部屬高校中31所普通高等學校', '中華人民共和國中央部屬高校', '中華人民共和國', '高校', '學校', '統稱']
# ['北理工', '歷史上最後一批副部級高校，黨委書記和校長列入中央管理的高校', '副部級高校', '黨委書記和校長', '中管高校', '“副部級高校”', '中華人民共和國中央部屬高校中31所普通高等學校的統稱', '中華人民共和國中央部屬高校中31所普通高等學校', '中華人民共和國中央部屬高校', '中華人民共和國']
#
# ['南京大學附屬中學', '南京大學', '中學', '中國江蘇省']
# ['南京大學附屬中學', '中國江蘇省']
#
# ['毒魚豆的萃取物', '毒魚豆', '萃取物', '西印度羣島的原住民', '西印度羣島', '西', '印度羣島', '印度', '原住民', '魚', '他們', '魚']
# ['毒魚豆的萃取物', '西印度羣島的原住民', '西印度羣島', '他們']
#
# ['軟件開發', '一項包括需求獲取、開發規劃、需求分析和設計、編程實現、軟件測試、版本控制的系統工程', '需求獲取、開發規劃、需求分析和設計、編程實現、軟件測試、版本控制', '版本控制', '系統工程', '其中', '任何最終獲得軟件產品的活動', '軟件產品', '活動']
# ['軟件開發', '一項包括需求獲取、開發規劃、需求分析和設計、編程實現、軟件測試、版本控制的系統工程', '需求獲取、開發規劃、需求分析和設計、編程實現、軟件測試、版本控制', '其中', '任何最終獲得軟件產品的活動']
#
# ['國立臺灣大學應用力學研究所', '國立臺灣大學', '臺灣大學', '應用力學', '力學', '研究所', '1984年', '碩、博士班研究生', '碩、博士班', '研究生', '首任所長', '所長', '理論及應用力學專家，美國國家工程院院士、中央研究院院士鮑亦興教授', '理論及應用力學專家，美國國家工程院院士、中央研究院院士', '理論及應用力學專家', '理論及應用力學', '理論', '力學', '專家', '美國國家工程院院士', '美國國家工程院', '院士', '中央研究院院士', '中央研究院', '院士', '鮑亦興教授']
# ['國立臺灣大學應用力學研究所', '國立臺灣大學', '1984年', '碩、博士班研究生', '碩、博士班', '首任所長', '理論及應用力學專家，美國國家工程院院士、中央研究院院士鮑亦興教授', '理論及應用力學專家，美國國家工程院院士、中央研究院院士', '理論及應用力學專家', '理論及應用力學', '美國國家工程院院士', '美國國家工程院', '中央研究院院士', '中央研究院', '鮑亦興教授']
#
# ['威廉·倫琴', '新電子波', '電子波', '倫琴射線', 'X射線']
# ['威廉·倫琴', '新電子波', '倫琴射線', 'X射線']

# %% [markdown]
# ### Step 2. Calculate our results

# %% [markdown]
# ##### 結果！！
#
# <table>
#     <thead>
#         <tr>
# <th> No. </th><th> Version </th><th> Precision </th><th> Recall </th><th> 說明 </th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
# <td>1.</td><td>原始版本</td><td>0.25093</td><td>0.80733</td><td></td>
#         </tr><tr>
# <td>2.</td><td>filter_nps</td><td>0.41740</td><td>0.76800</td><td>濾掉所有短的重複字串</td>
#         </tr><tr>
# <td>3.</td><td>filter_nps</td><td>0.37931</td><td>0.80656</td><td>保留長度五個字以上的字串</td>
#         </tr>
#     </tbody>
# </table>

# %%
calculate_precision(TRAIN_DATA, predicted_results)
calculate_recall(TRAIN_DATA, predicted_results)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-39-b9033d9a1dcd> in <cell line: 1>()
# ----> 1 calculate_precision(TRAIN_DATA, predicted_results)
#       2 calculate_recall(TRAIN_DATA, predicted_results)
#
# <ipython-input-32-11cee2e01c8a> in calculate_precision(data, predictions)
#      18         ])
#      19
# ---> 20         predicted_pages = predictions.iloc[i]
#      21         hits = predicted_pages.intersection(gt_pages)
#      22         if len(predicted_pages) != 0:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1071
#    1072             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073             return self._getitem_axis(maybe_callable, axis=axis)
#    1074
#    1075     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1623
#    1624             # validate the location
# -> 1625             self._validate_integer(key, axis)
#    1626
#    1627             return self.obj._ixs(key, axis=axis)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _validate_integer(self, key, axis)
#    1555         len_axis = len(self.obj._get_axis(axis))
#    1556         if key >= len_axis or key < -len_axis:
# -> 1557             raise IndexError("single positional indexer is out-of-bounds")
#    1558
#    1559     # -------------------------------------------------------------------
#
# IndexError: single positional indexer is out-of-bounds

# %% [markdown]
# ### Step 3. Repeat the same process on test set
# Create parsing tree

# %%
hanlp_test_file = f"data/hanlp_con_test_results.pkl"
if Path(hanlp_test_file).exists():
    with open(hanlp_file, "rb") as f:
        hanlp_results = pickle.load(f)
else:
    hanlp_results = [get_nps_hanlp(predictor, d) for d in TEST_DATA]
    # hanlp_results = [filter_nps(get_nps_hanlp(predictor, d)) for d in TEST_DATA]
    with open(hanlp_file, "wb") as f:
        pickle.dump(hanlp_results, f)

# %% [markdown]
# Get pages via wiki online api

# %%
test_doc_path = f"data/test_doc5.jsonl"
if Path(test_doc_path).exists():
    with open(test_doc_path, "r", encoding="utf8") as f:
        test_results = pd.Series(
            [set(json.loads(line)["predicted_pages"]) for line in f])
else:
    test_df = pd.DataFrame(TEST_DATA)
    test_df.loc[:, "hanlp_results"] = hanlp_results
    test_results = test_df.parallel_apply(get_pred_pages, axis=1)
    save_doc(TEST_DATA, test_results, mode="test")

# %% [markdown]
# notebook2
# ## PART 2. Sentence retrieval
# 難度：★★★☆☆ (最好 ／‵Д′)／~ ╧╧ )

# %% [markdown]
# ### 選擇Training Data (依照Part1 生成的1,2,3)

# %%
# local libs
from utils import (
    generate_evidence_to_wiki_pages_mapping,
    jsonl_dir_to_df,
    load_json,
    load_model,
    save_checkpoint,
    set_lr_scheduler,
)

# %%
Use_Data_From_Part_1 = "1"  #@param {type:"string"}

# %%
### Trainning Data From Part1

### always in form : data/train_doc5_data{x}.jsonl

File_From_Part_1 = f"data/train_doc5_data{Use_Data_From_Part_1}.jsonl"  

print("Use Training Data ",File_From_Part_1)

DOC_DATA = load_json(File_From_Part_1)
# Out:
# Use Training Data  data/train_doc5_data1.jsonl

# %% [markdown]
# ### Sentence retrieval 前置作業
#
# 內含:
#
# * 調 Train/Dev 比例
#
# * 轉換Wiki的code (3min)
#
#
#
#
# 使用方式 :
#
# - 蓋起來直接執行就好

# %%
# built-in libs
from pathlib import Path
from typing import Dict, List, Set, Tuple, Union

# third-party libs
import numpy as np
import pandas as pd
from pandarallel import pandarallel
from sklearn.model_selection import train_test_split
from tqdm.auto import tqdm

import torch
import torch.nn as nn
from torch.optim import AdamW
from torch.utils.data import DataLoader
from torch.utils.tensorboard import SummaryWriter
from transformers import (
    AutoModelForSequenceClassification,
    AutoTokenizer,
    get_scheduler,
)

from dataset import BERTDataset, Dataset



pandarallel.initialize(progress_bar=True, verbose=0, nb_workers=10)

# %% [markdown]
# Global variable

# %%
SEED = 42

TRAIN_DATA = load_json("data/public_train.jsonl")
TEST_DATA = load_json("data/public_test.jsonl")

 
LABEL2ID: Dict[str, int] = {
    "supports": 0,
    "refutes": 1,
    "NOT ENOUGH INFO": 2,
}
ID2LABEL: Dict[int, str] = {v: k for k, v in LABEL2ID.items()}

_y = [LABEL2ID[data["label"]] for data in TRAIN_DATA]
# GT means Ground Truth
TRAIN_GT, DEV_GT = train_test_split(
    DOC_DATA,
    test_size=0.2,
    random_state=SEED,
    shuffle=True,
    stratify=_y,
)

# %% [markdown]
# Preload wiki database (1 min)

# %%
# !wget 140.116.245.105:33332/wiki-pages.zip
# !unzip "wiki-pages.zip" -d "data/"

# %%
wiki_pages = jsonl_dir_to_df("data/wiki-pages")
mapping = generate_evidence_to_wiki_pages_mapping(wiki_pages)
del wiki_pages
# Out:
# Reading and concatenating jsonl files in data/wiki-pages
# Generate parse mapping
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=118776), Label(value='0 / 118776')…
# Transform to id to evidence_map mapping

# %% [markdown]
# ### Helper function
#
# 內含:
#
# * 調整input樣子的code (是否要擴增資料集)
#
# 使用方式:
#
# * 蓋起來直接執行

# %%
import json

# %%
def evidence_macro_precision(
    instance: Dict,
    top_rows: pd.DataFrame,
) -> Tuple[float, float]:
    """Calculate precision for sentence retrieval
    This function is modified from fever-scorer.
    https://github.com/sheffieldnlp/fever-scorer/blob/master/src/fever/scorer.py

    Args:
        instance (dict): a row of the dev set (dev.jsonl) of test set (test.jsonl)
        top_rows (pd.DataFrame): our predictions with the top probabilities

        IMPORTANT!!!
        instance (dict) should have the key of `evidence`.
        top_rows (pd.DataFrame) should have a column `predicted_evidence`.

    Returns:
        Tuple[float, float]:
        [1]: relevant and retrieved (numerator of precision)
        [2]: retrieved (denominator of precision)
    """
    this_precision = 0.0
    this_precision_hits = 0.0

    # Return 0, 0 if label is not enough info since not enough info does not
    # contain any evidence.
    if instance["label"].upper() != "NOT ENOUGH INFO":
        # e[2] is the page title, e[3] is the sentence index
        all_evi = [[e[2], e[3]]
                   for eg in instance["evidence"]
                   for e in eg
                   if e[3] is not None]
        claim = instance["claim"]
        predicted_evidence = top_rows[top_rows["claim"] ==
                                      claim]["predicted_evidence"].tolist()

        for prediction in predicted_evidence:
            if prediction in all_evi:
                this_precision += 1.0
            this_precision_hits += 1.0

        return (this_precision /
                this_precision_hits) if this_precision_hits > 0 else 1.0, 1.0

    return 0.0, 0.0

# %% [markdown]
# Calculate recall for sentence retrieval

# %%
def evidence_macro_recall(
    instance: Dict,
    top_rows: pd.DataFrame,
) -> Tuple[float, float]:
    """Calculate recall for sentence retrieval
    This function is modified from fever-scorer.
    https://github.com/sheffieldnlp/fever-scorer/blob/master/src/fever/scorer.py

    Args:
        instance (dict): a row of the dev set (dev.jsonl) of test set (test.jsonl)
        top_rows (pd.DataFrame): our predictions with the top probabilities

        IMPORTANT!!!
        instance (dict) should have the key of `evidence`.
        top_rows (pd.DataFrame) should have a column `predicted_evidence`.

    Returns:
        Tuple[float, float]:
        [1]: relevant and retrieved (numerator of recall)
        [2]: relevant (denominator of recall)
    """
    # We only want to score F1/Precision/Recall of recalled evidence for NEI claims
    if instance["label"].upper() != "NOT ENOUGH INFO":
        # If there's no evidence to predict, return 1
        if len(instance["evidence"]) == 0 or all(
            [len(eg) == 0 for eg in instance]):
            return 1.0, 1.0

        claim = instance["claim"]

        predicted_evidence = top_rows[top_rows["claim"] ==
                                      claim]["predicted_evidence"].tolist()

        for evidence_group in instance["evidence"]:
            evidence = [[e[2], e[3]] for e in evidence_group]
            if all([item in predicted_evidence for item in evidence]):
                # We only want to score complete groups of evidence. Incomplete
                # groups are worthless.
                return 1.0, 1.0
        return 0.0, 1.0
    return 0.0, 0.0

# %% [markdown]
# Calculate the scores of sentence retrieval

# %%
def evaluate_retrieval(
    probs: np.ndarray,
    df_evidences: pd.DataFrame,
    ground_truths: pd.DataFrame,
    top_n: int = 5,
    cal_scores: bool = True,
    save_name: str = None,
    shut_up = False
) -> Dict[str, float]:
    """Calculate the scores of sentence retrieval

    Args:
        probs (np.ndarray): probabilities of the candidate retrieved sentences
        df_evidences (pd.DataFrame): the candiate evidence sentences paired with claims
        ground_truths (pd.DataFrame): the loaded data of dev.jsonl or test.jsonl
        top_n (int, optional): the number of the retrieved sentences. Defaults to 2.

    Returns:
        Dict[str, float]: F1 score, precision, and recall
    """
    df_evidences["prob"] = probs
    top_rows = (
        df_evidences.groupby("claim").apply(
        lambda x: x.nlargest(top_n, "prob"))
        .reset_index(drop=True)
    )
    if shut_up==False:
      print("top_rows=")
      for i in range(30):
        print(top_rows["claim"][i],top_rows["text"][i])
        # print(top_rows["claim"][i],top_rows["text"][i],top_rows["evidence"][i])
        # for j in top_rows["evidence"][i]:

    if cal_scores:
        macro_precision = 0
        macro_precision_hits = 0
        macro_recall = 0
        macro_recall_hits = 0

        for i, instance in enumerate(ground_truths):
            macro_prec = evidence_macro_precision(instance, top_rows)
            macro_precision += macro_prec[0]
            macro_precision_hits += macro_prec[1]

            macro_rec = evidence_macro_recall(instance, top_rows)
            macro_recall += macro_rec[0]
            macro_recall_hits += macro_rec[1]

        pr = (macro_precision /
              macro_precision_hits) if macro_precision_hits > 0 else 1.0
        rec = (macro_recall /
               macro_recall_hits) if macro_recall_hits > 0 else 0.0
        f1 = 2.0 * pr * rec / (pr + rec)

    if save_name is not None:
        # write doc7_sent5 file
        with open(f"data/{save_name}", "w") as f:
            for instance in ground_truths:
                claim = instance["claim"]
                predicted_evidence = top_rows[
                    top_rows["claim"] == claim]["predicted_evidence"].tolist()
                instance["predicted_evidence"] = predicted_evidence
                f.write(json.dumps(instance, ensure_ascii=False) + "\n")

    if cal_scores:
        return {"F1 score": f1, "Precision": pr, "Recall": rec}

# %% [markdown]
# Inference script to get probabilites for the candidate evidence sentences

# %%
def get_predicted_probs(
    model: nn.Module,
    dataloader: Dataset,
    device: torch.device,
) -> np.ndarray:
    """Inference script to get probabilites for the candidate evidence sentences

    Args:
        model: the one from HuggingFace Transformers
        dataloader: devset or testset in torch dataloader

    Returns:
        np.ndarray: probabilites of the candidate evidence sentences
    """
    model.eval()
    probs = []

    with torch.no_grad():
        for batch in tqdm(dataloader):
            batch = {k: v.to(device) for k, v in batch.items()}
            outputs = model(**batch)
            logits = outputs.logits
            probs.extend(torch.softmax(logits, dim=1)[:, 1].tolist())

    return np.array(probs)

# %% [markdown]
# SentRetrievalBERTDataset class for the paired sentences

# %% [markdown]
# Please refer to [PyTorch Dataset tutorial](https://pytorch.org/tutorials/beginner/basics/data_tutorial.html)

# %%
class SentRetrievalBERTDataset(BERTDataset):
    """SentRetrievalBERTDataset class for AICUP dataset with top-k evidence sentences."""

    def __getitem__(
        self,
        idx: int,
        **kwargs,
    ) -> Tuple[Dict[str, torch.Tensor], int]:
        item = self.data.iloc[idx]
        sentA = item["claim"]
        sentB = item["text"]

        # claim [SEP] text
        concat = self.tokenizer(
            sentA,
            sentB,
            padding="max_length",
            max_length=self.max_length,
            truncation=True,
        )
        concat_ten = {k: torch.tensor(v) for k, v in concat.items()}
        if "label" in item:
            concat_ten["labels"] = torch.tensor(item["label"])

        return concat_ten

# %%
import random

def pair_with_wiki_sentences(
    mapping: Dict[str, Dict[int, str]],
    df: pd.DataFrame,
    negative_ratio: float,
) -> pd.DataFrame:
    """Only for creating train sentences."""
    claims = []
    sentences = []
    labels = []

    # positive
    for i in range(len(df)):
        if df["label"].iloc[i] == "NOT ENOUGH INFO":
            continue

        claim = df["claim"].iloc[i]
        evidence_sets = df["evidence"].iloc[i]
        for evidence_set in evidence_sets:
            sents = []
            for evidence in evidence_set:
                # evidence[2] is the page title
                page = evidence[2].replace(" ", "_")
                # the only page with weird name
                if page == "臺灣海峽危機#第二次臺灣海峽危機（1958）":
                    continue
                # evidence[3] is in form of int however, mapping requires str
                sent_idx = str(evidence[3])
                
                #sents.append(mapping[page][sent_idx])

                if mapping[page][sent_idx]!="":
                  claims.append(claim)
                  sentences.append(mapping[page][sent_idx]) ### 所有相關句合再一起
                  labels.append(1)

                  sents.append(mapping[page][sent_idx])

                  # 用,分隔 (做出更多dataset)
                  for i in mapping[page][sent_idx].split(","): 
                    claims.append(claim)
                    sentences.append(i) ### 所有相關句合再一起
                    labels.append(1)

                  # for i in mapping[page][sent_idx].split("。"):
                  #   claims.append(claim)
                  #   sentences.append(i) ### 所有相關句合再一起
                  #   labels.append(1)

            ### Random 合成句子 (做出更多dataset)
            escape_rate=0.2
            dataset_set=set()

            while True:
              if random.random() < escape_rate:
                break
              
              composed_sentence=[]
              

              for sub_sentence in sents:
                if random.random() >=0.5:
                  composed_sentence.append(sub_sentence)
              
              if len(composed_sentence)!=0:
                try_sentence="".join(composed_sentence)
                if try_sentence not in dataset_set:
                  dataset_set.add(try_sentence)
                  # random.shuffle(composed_sentence)
                  # target_sentence="".join()
                  claims.append(claim)
                  sentences.append(try_sentence) ### 所有相關句合再一起
                  labels.append(1)

              escape_rate=escape_rate + random.random()*0.08

                

            #whole_evidence = " ".join(sents)

            # claims.append(claim)
            # sentences.append(whole_evidence) ### 所有相關句合再一起
            # labels.append(1)

    # negative
    for i in range(len(df)):
        if df["label"].iloc[i] == "NOT ENOUGH INFO":
            continue
        claim = df["claim"].iloc[i]

        evidence_set = set([(evidence[2], evidence[3])
                            for evidences in df["evidence"][i]
                            for evidence in evidences])
        predicted_pages = df["predicted_pages"][i]
        for page in predicted_pages:
            page = page.replace(" ", "_")
            try:
                page_sent_id_pairs = [
                    (page, sent_idx) for sent_idx in mapping[page].keys()
                ]
            except KeyError:
                # print(f"{page} is not in our Wiki db.")
                continue

            for pair in page_sent_id_pairs:
                if pair in evidence_set:
                    continue
                text = mapping[page][pair[1]]
                # `np.random.rand(1) <= 0.05`: Control not to add too many negative samples
                if text != "" and np.random.rand(1) <= negative_ratio:
                    claims.append(claim)
                    sentences.append(text)
                    labels.append(0)

    return pd.DataFrame({"claim": claims, "text": sentences, "label": labels})


def pair_with_wiki_sentences_eval(
    mapping: Dict[str, Dict[int, str]],
    df: pd.DataFrame,
    is_testset: bool = False,
) -> pd.DataFrame:
    """Only for creating dev and test sentences."""
    claims = []
    sentences = []
    evidence = []
    predicted_evidence = []

    # negative
    for i in range(len(df)):
        # if df["label"].iloc[i] == "NOT ENOUGH INFO":
        #     continue
        claim = df["claim"].iloc[i]

        predicted_pages = df["predicted_pages"][i]
        for page in predicted_pages:
            page = page.replace(" ", "_")
            try:
                page_sent_id_pairs = [(page, k) for k in mapping[page]]
            except KeyError:
                # print(f"{page} is not in our Wiki db.")
                continue

            for page_name, sentence_id in page_sent_id_pairs:
                text = mapping[page][sentence_id]
                if text != "":
                    claims.append(claim)
                    sentences.append(text)
                    if not is_testset:
                        evidence.append(df["evidence"].iloc[i])
                    predicted_evidence.append([page_name, int(sentence_id)])

    return pd.DataFrame({
        "claim": claims,
        "text": sentences,
        "evidence": evidence if not is_testset else None,
        "predicted_evidence": predicted_evidence,
    })

# %%
def pair_with_wiki_sentences_by_jerry(
    mapping: Dict[str, Dict[int, str]],
    df: pd.DataFrame,
    negative_ratio: float,
) -> pd.DataFrame:
    """Only for creating train sentences."""
    claims = []
    sentences = []
    labels = []

    # positive
    for i in range(len(df)):
        if df["label"].iloc[i] == "NOT ENOUGH INFO":
            continue

        claim = df["claim"].iloc[i]
        evidence_sets = df["evidence"].iloc[i]
        for evidence_set in evidence_sets:
            sents = []
            for evidence in evidence_set:
                # evidence[2] is the page title
                page = evidence[2].replace(" ", "_")
                # the only page with weird name
                if page == "臺灣海峽危機#第二次臺灣海峽危機（1958）":
                    continue
                # evidence[3] is in form of int however, mapping requires str
                sent_idx = str(evidence[3])
                sents.append(mapping[page][sent_idx])

            whole_evidence = " ".join(sents)

            claims.append(claim)
            sentences.append(whole_evidence)
            labels.append(1)

    # negative
    for i in range(len(df)):
        if df["label"].iloc[i] == "NOT ENOUGH INFO":
            continue
        claim = df["claim"].iloc[i]

        evidence_set = set([(evidence[2], evidence[3])
                            for evidences in df["evidence"][i]
                            for evidence in evidences])
        predicted_pages = df["predicted_pages"][i]
        for page in predicted_pages:
            page = page.replace(" ", "_")
            try:
                page_sent_id_pairs = [
                    (page, sent_idx) for sent_idx in mapping[page].keys()
                ]
            except KeyError:
                # print(f"{page} is not in our Wiki db.")
                continue

            for pair in page_sent_id_pairs:
                if pair in evidence_set:
                    continue
                text = mapping[page][pair[1]]
                # `np.random.rand(1) <= 0.05`: Control not to add too many negative samples
                if text != "" and np.random.rand(1) <= negative_ratio:
                    claims.append(claim)
                    sentences.append(text)
                    labels.append(0)

    return pd.DataFrame({"claim": claims, "text": sentences, "label": labels})


def pair_with_wiki_sentences_eval(
    mapping: Dict[str, Dict[int, str]],
    df: pd.DataFrame,
    is_testset: bool = False,
) -> pd.DataFrame:
    """Only for creating dev and test sentences."""
    claims = []
    sentences = []
    evidence = []
    predicted_evidence = []

    # negative
    for i in range(len(df)):
        # if df["label"].iloc[i] == "NOT ENOUGH INFO":
        #     continue
        claim = df["claim"].iloc[i]

        predicted_pages = df["predicted_pages"][i]
        for page in predicted_pages:
            page = page.replace(" ", "_")
            try:
                page_sent_id_pairs = [(page, k) for k in mapping[page]]
            except KeyError:
                # print(f"{page} is not in our Wiki db.")
                continue

            for page_name, sentence_id in page_sent_id_pairs:
                text = mapping[page][sentence_id]
                if text != "":
                    claims.append(claim)
                    sentences.append(text)
                    if not is_testset:
                        evidence.append(df["evidence"].iloc[i])
                    predicted_evidence.append([page_name, int(sentence_id)])

    return pd.DataFrame({
        "claim": claims,
        "text": sentences,
        "evidence": evidence if not is_testset else None,
        "predicted_evidence": predicted_evidence,
    })

# %% [markdown]
# ### 1-1. Train By Bert : 超參數

# %% [markdown]
# Hyperparams

# %%
MODEL_NAME = "bert-base-chinese"  #@param {type:"string"}
NUM_EPOCHS = 20  #@param {type:"integer"}
LR = 1e-5  #@param {type:"number"}
TRAIN_BATCH_SIZE = 64  #@param {type:"integer"}
TEST_BATCH_SIZE = 64  #@param {type:"integer"}
NEGATIVE_RATIO = 0.1415  #@param {type:"number"}
VALIDATION_STEP = 50  #@param {type:"integer"}
TOP_N = 5  #@param {type:"integer"}

# %%
### 不要資料擴充的跑這邊


train_df = pair_with_wiki_sentences_by_jerry(
    mapping,
    pd.DataFrame(TRAIN_GT),
    NEGATIVE_RATIO,
)
counts = train_df["label"].value_counts()
print("Now using the following train data with 0 (Negative) and 1 (Positive)")
print(counts)

dev_evidences = pair_with_wiki_sentences_eval(mapping, pd.DataFrame(DEV_GT))

### 請確定0,1比例正常 (by 調整Negative Rate)
# Out:
# Now using the following train data with 0 (Negative) and 1 (Positive)
# 0    29957
# 1     7027
# Name: label, dtype: int64

# %%
### 要資料擴充的跑這邊 (會比較久)



train_df = pair_with_wiki_sentences(
    mapping,
    pd.DataFrame(TRAIN_GT),
    NEGATIVE_RATIO,
)
counts = train_df["label"].value_counts()
print("Now using the following train data with 0 (Negative) and 1 (Positive)")
print(counts)

dev_evidences = pair_with_wiki_sentences_eval(mapping, pd.DataFrame(DEV_GT))

### 請確定0,1比例正常 (by 調整Negative Rate)
# Out:
# Now using the following train data with 0 (Negative) and 1 (Positive)
# 0    29769
# 1    27975
# Name: label, dtype: int64

# %% [markdown]
# ### 1-2.Train By Bert : 前置
#
# 直接執行

# %%
EXP_DIR = f"sent_retrieval/e{NUM_EPOCHS}_bs{TRAIN_BATCH_SIZE}_" + f"{LR}_neg{NEGATIVE_RATIO}_top{TOP_N}_data{Use_Data_From_Part_1}"
LOG_DIR = "logs/" + EXP_DIR
CKPT_DIR = "checkpoints/" + EXP_DIR

HANG_MODEL_NAME= f"e{NUM_EPOCHS}_bs{TRAIN_BATCH_SIZE}_" + f"{LR}_neg{NEGATIVE_RATIO}_top{TOP_N}"

if not Path(LOG_DIR).exists():
    Path(LOG_DIR).mkdir(parents=True)

if not Path(CKPT_DIR).exists():
    Path(CKPT_DIR).mkdir(parents=True)

# %% [markdown]
# Dataloader things. Please refer to [PyTorch Dataset tutorial](https://pytorch.org/tutorials/beginner/basics/data_tutorial.html)

# %%
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

train_dataset = SentRetrievalBERTDataset(train_df, tokenizer=tokenizer)
val_dataset = SentRetrievalBERTDataset(dev_evidences, tokenizer=tokenizer)

train_dataloader = DataLoader(
    train_dataset,
    shuffle=True,
    batch_size=TRAIN_BATCH_SIZE,
)
eval_dataloader = DataLoader(val_dataset, batch_size=TEST_BATCH_SIZE)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/624 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/110k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/269k [00:00<?, ?B/s]

# %% [markdown]
# Save your memory.

# %%
del train_df

# %% [markdown]
# Trainer

# %%
device = torch.device("cuda") if torch.cuda.is_available() else torch.device(
    "cpu")
model = AutoModelForSequenceClassification.from_pretrained(MODEL_NAME)
model.to(device)

optimizer = AdamW(model.parameters(), lr=LR)
num_training_steps = NUM_EPOCHS * len(train_dataloader)
lr_scheduler = set_lr_scheduler(optimizer, num_training_steps)

writer = SummaryWriter(LOG_DIR)
# Out:
# Downloading pytorch_model.bin:   0%|          | 0.00/412M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-chinese were not used when initializing BertForSequenceClassification: ['cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-chinese and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# For training, please refer to [PyTorch Optimization tutorial](https://pytorch.org/tutorials/beginner/basics/optimization_tutorial.html)
#
# Please make sure that you are using gpu when training (5 min)

# %% [markdown]
# ### 1-3.Train By Bert : Training
#
# 每隔Validate會在/NCKU/checkpoints/Sent裡面放入模型
#
# Q:要規定只能選最好嗎?

# %%
progress_bar = tqdm(range(num_training_steps))
current_steps = 0

### best_v_acc
best_recall = 0.0
best_precision = 0.0
best_f1 = 0.0

for epoch in range(NUM_EPOCHS):
    model.train()

    print("[Epoch {:d}/{:d}]".format(epoch, NUM_EPOCHS))
    
    for i, batch in enumerate(train_dataloader):
        batch = {k: v.to(device) for k, v in batch.items()}
        outputs = model(**batch)
        loss = outputs.loss
        loss.backward()

        optimizer.step()
        lr_scheduler.step()
        optimizer.zero_grad()
        progress_bar.update(1)
        writer.add_scalar("training_loss", loss.item(), current_steps)

        y_pred = torch.argmax(outputs.logits, dim=1).tolist()
        y_true = batch["labels"].tolist()

        current_steps += 1

        if current_steps % VALIDATION_STEP == 0 and current_steps > 0:
            # print("Start validation")
            probs = get_predicted_probs(model, eval_dataloader, device)

            val_results = evaluate_retrieval(
                probs=probs,
                df_evidences=dev_evidences,
                ground_truths=DEV_GT,
                top_n=TOP_N,
            )
            print(val_results)

            # log each metric separately to TensorBoard
            for metric_name, metric_value in val_results.items():
                writer.add_scalar(
                    f"dev_{metric_name}",
                    metric_value,
                    current_steps,
                )
            
            if best_recall < val_results["Recall"]:
                best_recall = val_results["Recall"]
                save_checkpoint(model, CKPT_DIR, current_steps)

        # save_checkpoint(model, CKPT_DIR, current_steps)

print("Finished training!")
# Out:
#   0%|          | 0/18060 [00:00<?, ?it/s]
# [Epoch 0/20]
#   0%|          | 0/1116 [00:00<?, ?it/s]

# %% [markdown]
# ### 1-4.Train By Bert : 統整Acc與幫資料存檔
#
# 除非要生成給Part3 的Train與Validate
#
# 不然不要執行

# %%
print("CKPT_DIR=",CKPT_DIR)

# %%
### 可以改動選Model的資料夾 ### Like checkpoints/sent_retrieval/資料夾名

CKPT_DIR = "checkpoints/sent_retrieval/e20_bs64_2e-05_neg0.12_top5"  #@param {type:"string"}

# %%
### 如果是中途插入Model (不Train) ，要先跑建立Model的Code


# MODEL_NAME = "bert-base-chinese"

# device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
# model = AutoModelForSequenceClassification.from_pretrained(MODEL_NAME)
# model.to(device)

# %%
ls checkpoints/sent_retrieval/e20_bs64_2e-05_neg0.03_top5_data2

# %%
#選Validate Model


ckpt_name = "model.5.pt"  #@param {type:"string"}
model = load_model(model, ckpt_name, CKPT_DIR)
print("Start final evaluations and write prediction files.")

# %%
train_evidences = pair_with_wiki_sentences_eval(
    mapping=mapping,
    df=pd.DataFrame(TRAIN_GT[:1000]),
)
train_set = SentRetrievalBERTDataset(train_evidences, tokenizer)
train_dataloader = DataLoader(train_set, batch_size=TEST_BATCH_SIZE)

print("Start calculating training scores")
probs = get_predicted_probs(model, train_dataloader, device)
train_results = evaluate_retrieval(
    probs=probs,
    df_evidences=train_evidences,
    ground_truths=TRAIN_GT,
    top_n=TOP_N,
    save_name=f"train_doc5sent{TOP_N}_data{Use_Data_From_Part_1}.jsonl",
    shut_up=True
)
print(f"Training scores => {train_results}")

print("Start validation")
probs = get_predicted_probs(model, eval_dataloader, device)
val_results = evaluate_retrieval(
    probs=probs,
    df_evidences=dev_evidences,
    ground_truths=DEV_GT,
    top_n=TOP_N,
    save_name=f"dev_doc5sent{TOP_N}_data{Use_Data_From_Part_1}.jsonl",
    shut_up=True
)

print(f"Validation scores => {val_results}")

# %% [markdown]
# ### 1-5.Train By Bert : Testing and Make File

# %%
import json

# %%
ls data

# %%
### 選Part 1 執行結果的檔案
### 改右邊就好
### 不要/data

Data_From_Part_1_Test = "1"  #@param {type:"string"}

file_name= f"test_doc5_data{Data_From_Part_1_Test}.jsonl"

print("Use file ",file_name)

test_data = load_json("data/"+file_name)

# %%
# 如果Model路徑不慎滿意可以調

DIR_FOR_MODEL="checkpoints/sent_retrieval/e20_bs64_2e-05_neg0.03_top5_data2" #@param {type:"string"}
CKPT_DIR = DIR_FOR_MODEL

# 並配合 LS 服用

# !ls "checkpoints/sent_retrieval/e20_bs64_2e-05_neg0.12_top5/"

# %%
ls checkpoints/sent_retrieval/e20_bs64_2e-05_neg0.03_top5_data2

# %%
### 選擇Model

ckpt_name = "model.10.pt"  #@param {type:"string"}
model = load_model(model, ckpt_name, CKPT_DIR)

# %%
import json


test_evidences = pair_with_wiki_sentences_eval(
    mapping,
    pd.DataFrame(test_data),
    is_testset=True,
)
test_set = SentRetrievalBERTDataset(test_evidences, tokenizer)
test_dataloader = DataLoader(test_set, batch_size=TEST_BATCH_SIZE)

print("Start predicting the test data")
probs = get_predicted_probs(model, test_dataloader, device)
evaluate_retrieval(
    probs=probs,
    df_evidences=test_evidences,
    ground_truths=test_data,
    top_n=TOP_N,
    cal_scores=False,
    save_name=f"test_doc5sent{TOP_N}_data{Data_From_Part_1_Test}.jsonl",
    shut_up=True
)

# %%
print("Saved name : ",f"test_doc5sent{TOP_N}_data{Data_From_Part_1_Test}.jsonl")

# %% [markdown]
# notebook3
# ## PART 3. Claim verification
# 難度：★★☆☆☆

# %% [markdown]
# ### 前置
# - Step 1: 將證據句和 claim 丟入 BERT 判斷 Supports/Refutes/Not Enough Info。
#
# 內含wiki轉換(3min)
#
# 直接執行

# %%
import pickle
from pathlib import Path
from typing import Dict, Tuple

import numpy as np
import pandas as pd
from pandarallel import pandarallel
from tqdm.auto import tqdm

import torch
from sklearn.metrics import accuracy_score
from torch.optim import AdamW
from torch.utils.data import DataLoader
from torch.utils.tensorboard import SummaryWriter
from transformers import (
    AutoModelForSequenceClassification,
    AutoTokenizer,
    get_scheduler,
)

from dataset import BERTDataset
from utils import (
    generate_evidence_to_wiki_pages_mapping,
    jsonl_dir_to_df,
    load_json,
    load_model,
    save_checkpoint,
    set_lr_scheduler,
)

pandarallel.initialize(progress_bar=True, verbose=0, nb_workers=4)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-752f60e910fa> in <cell line: 7>()
#       5 import numpy as np
#       6 import pandas as pd
# ----> 7 from pandarallel import pandarallel
#       8 from tqdm.auto import tqdm
#       9
#
# ModuleNotFoundError: No module named 'pandarallel'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# Global variables

# %%
SEED = 42

LABEL2ID: Dict[str, int] = {
    "supports": 0,
    "refutes": 1,
    "NOT ENOUGH INFO": 2,
}
ID2LABEL: Dict[int, str] = {v: k for k, v in LABEL2ID.items()}

TRAIN_DATA = load_json("data/train_doc5sent5.jsonl")
DEV_DATA = load_json("data/dev_doc5sent5.jsonl")

TRAIN_PKL_FILE = Path("data/train_doc5sent5.pkl")
DEV_PKL_FILE = Path("data/dev_doc5sent5.pkl")

# %%
wiki_pages = jsonl_dir_to_df("data/wiki-pages")
mapping = generate_evidence_to_wiki_pages_mapping(wiki_pages,)
del wiki_pages

### mapping : {
  #  "page_name":{
      # "第n句":"文字"
  #  } 
###}
# Out:
# Reading and concatenating jsonl files in data/wiki-pages
# Generate parse mapping
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=296938), Label(value='0 / 296938')…
# Transform to id to evidence_map mapping

# %% [markdown]
# ### Helper function
#
# 內可選資料集擴充與否
#
# 直接執行

# %% [markdown]
# AICUP dataset with top-k evidence sentences.
#
# #### 配對句子 -> 以建立 sentence retrieval 的資料集
# 輸入模型的格式：[CLS] `{claim}` [SEP] `{evidence_0}`[SEP]`{evidence_1}`[SEP]...
# - 以 $k$ 來控制接在 `{claim}` 之後的 `{evidence_i}` 數量
# - 程式碼預設會取前 k 個句子接在 `{claim}` 之後，故這邊稱此結合方式為 `top-k`

# %%
class AicupTopkEvidenceBERTDataset(BERTDataset):
    """AICUP dataset with top-k evidence sentences."""

    def __getitem__(
        self,
        idx: int,
        **kwargs,
    ) -> Tuple[Dict[str, torch.Tensor], int]:
        item = self.data.iloc[idx]
        claim = item["claim"]
        evidence = item["evidence_list"]

        # In case there are less than topk evidence sentences
        pad = ["[PAD]"] * (self.topk - len(evidence))  ### 補齊For Trainning data?
        if type(evidence)==str:
          evidence=[evidence]

        evidence += pad
        concat_claim_evidence = " [SEP] ".join([claim,"[SEP]","[SEP]", *evidence])

        # if idx==2:
        #   print(concat_claim_evidence)

        concat = self.tokenizer(
            concat_claim_evidence,
            padding="max_length",
            max_length=self.max_length,
            truncation=True,
        )
        label = LABEL2ID[item["label"]] if "label" in item else -1
        concat_ten = {k: torch.tensor(v) for k, v in concat.items()}

        if "label" in item:
            concat_ten["labels"] = torch.tensor(label)

        return concat_ten
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-2e958c3c54da> in <cell line: 1>()
# ----> 1 class AicupTopkEvidenceBERTDataset(BERTDataset):
#       2     """AICUP dataset with top-k evidence sentences."""
#       3
#       4     def __getitem__(
#       5         self,
#
# NameError: name 'BERTDataset' is not defined

# %% [markdown]
# Evaluation function

# %%
def run_evaluation(model: torch.nn.Module, dataloader: DataLoader, device):
    model.eval()

    loss = 0
    y_true = []
    y_pred = []
    with torch.no_grad():
        for batch in tqdm(dataloader):
            y_true.extend(batch["labels"].tolist())

            batch = {k: v.to(device) for k, v in batch.items()}
            outputs = model(**batch)
            loss += outputs.loss.item()
            logits = outputs.logits
            y_pred.extend(torch.argmax(logits, dim=1).tolist())

    acc = accuracy_score(y_true, y_pred)

    return {"val_loss": loss / len(dataloader), "val_acc": acc}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-7913e2c084c5> in <cell line: 1>()
# ----> 1 def run_evaluation(model: torch.nn.Module, dataloader: DataLoader, device):
#       2     model.eval()
#       3
#       4     loss = 0
#       5     y_true = []
#
# NameError: name 'torch' is not defined

# %% [markdown]
# Prediction

# %%
def run_predict(model: torch.nn.Module, test_dl: DataLoader, device) -> list:
    model.eval()

    preds = []
    for batch in tqdm(test_dl,
                      total=len(test_dl),
                      leave=False,
                      desc="Predicting"):
        batch = {k: v.to(device) for k, v in batch.items()}
        pred = model(**batch).logits
        pred = torch.argmax(pred, dim=1)
        preds.extend(pred.tolist())
    return preds

# %%
def join_with_topk_evidence(
    df: pd.DataFrame,
    mapping: dict,
    mode: str = "train",
    topk: int = 5,
) -> pd.DataFrame:
    """join_with_topk_evidence join the dataset with topk evidence.

    Note:
        After extraction, the dataset will be like this:
               id     label         claim                           evidence            evidence_list
        0    4604  supports       高行健...     [[[3393, 3552, 高行健, 0], [...  [高行健 （ ）江西赣州出...
        ..    ...       ...            ...                                ...                     ...
        945  2095  supports       美國總...  [[[1879, 2032, 吉米·卡特, 16], [...  [卸任后 ， 卡特積極參與...
        停各种战争及人質危機的斡旋工作 ， 反对美国小布什政府攻打伊拉克...

        [946 rows x 5 columns]

    Args:
        df (pd.DataFrame): The dataset with evidence.
        wiki_pages (pd.DataFrame): The wiki pages dataframe
        topk (int, optional): The topk evidence. Defaults to 5.
        cache(Union[Path, str], optional): The cache file path. Defaults to None.
            If cache is None, return the result directly.

    Returns:
        pd.DataFrame: The dataset with topk evidence_list.
            The `evidence_list` column will be: List[str]
    """

    # format evidence column to List[List[Tuple[str, str, str, str]]]
    if "evidence" in df.columns:
        df["evidence"] = df["evidence"].parallel_map(
            lambda x: [[x]] if not isinstance(x[0], list) else [x]
            if not isinstance(x[0][0], list) else x) ### to 3層list

    print(f"Extracting evidence_list for the {mode} mode ...")
    if mode == "eval":
        # extract evidence
        df["evidence_list"] = df["predicted_evidence"].parallel_map(lambda x: " ".join([
            mapping.get(evi_id, {}).get(str(evi_idx), "")
            for evi_id, evi_idx in x  # for each evidence list
        ][:topk]) if isinstance(x, list) else "")  ### 做出[前topk句]
        print(df["evidence_list"][:5])
    else:
        # extract evidence
        df["evidence_list"] = df["evidence"].parallel_map(lambda x: [
            " ".join([  # join evidence
                mapping.get(evi_id, {}).get(str(evi_idx), "")
                for _, _, evi_id, evi_idx in evi_list
            ]) if isinstance(evi_list, list) else ""
            for evi_list in x  # for each evidence list
        ][:1] if isinstance(x, list) else [])

    return df

# %% [markdown]
# ### 1-1.Train By Bert : 超參數

# %% [markdown]
# Hyperparams

# %%
MODEL_NAME = "bert-base-chinese"  #@param {type:"string"}
TRAIN_BATCH_SIZE = 16  #@param {type:"integer"}
TEST_BATCH_SIZE = 16  #@param {type:"integer"}
LR = 1e-5  #@param {type:"number"}
NUM_EPOCHS = 20  #@param {type:"integer"}
MAX_SEQ_LEN = 256  #@param {type:"integer"}
EVIDENCE_TOPK = 5  #@param {type:"integer"}
VALIDATION_STEP = 25  #@param {type:"integer"}

# %% [markdown]
# Experiment Directory

# %%
EXP_DIR = f"claim_verification/e{NUM_EPOCHS}_bs{TRAIN_BATCH_SIZE}_" + f"{LR}_top{EVIDENCE_TOPK}"
LOG_DIR = "logs/" + EXP_DIR
CKPT_DIR = "checkpoints/" + EXP_DIR

if not Path(LOG_DIR).exists():
    Path(LOG_DIR).mkdir(parents=True)

if not Path(CKPT_DIR).exists():
    Path(CKPT_DIR).mkdir(parents=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-809813e87088> in <cell line: 1>()
# ----> 1 EXP_DIR = f"claim_verification/e{NUM_EPOCHS}_bs{TRAIN_BATCH_SIZE}_" + f"{LR}_top{EVIDENCE_TOPK}"
#       2 LOG_DIR = "logs/" + EXP_DIR
#       3 CKPT_DIR = "checkpoints/" + EXP_DIR
#       4
#       5 if not Path(LOG_DIR).exists():
#
# NameError: name 'NUM_EPOCHS' is not defined

# %% [markdown]
# ### 1-2.Train By Bert : input

# %%
if not TRAIN_PKL_FILE.exists():
    train_df = join_with_topk_evidence(
        pd.DataFrame(TRAIN_DATA),
        mapping,
        topk=EVIDENCE_TOPK,
    )
    train_df.to_pickle(TRAIN_PKL_FILE, protocol=4)
else:
    with open(TRAIN_PKL_FILE, "rb") as f:
        train_df = pickle.load(f)

if not DEV_PKL_FILE.exists():
    dev_df = join_with_topk_evidence(
        pd.DataFrame(DEV_DATA),
        mapping,
        mode="eval",
        topk=EVIDENCE_TOPK,
    )
    dev_df.to_pickle(DEV_PKL_FILE, protocol=4)
else:
    with open(DEV_PKL_FILE, "rb") as f:
        dev_df = pickle.load(f)

### 其中train_df的"evidence_list"會合併為一句
### dev_df不會，會是[top_n句]

# %%
counts = train_df["label"].value_counts()
print("Now using the following train data with 0 (Negative) and 1 (Positive)")
print(counts)
# Out:
# Now using the following train data with 0 (Negative) and 1 (Positive)
# refutes            1280
# supports           1280
# NOT ENOUGH INFO     615
# Name: label, dtype: int64

# %%
torch.cuda.empty_cache()

# %%
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

train_dataset = AicupTopkEvidenceBERTDataset(
    train_df,
    tokenizer=tokenizer,
    max_length=MAX_SEQ_LEN,
)
val_dataset = AicupTopkEvidenceBERTDataset(
    dev_df,
    tokenizer=tokenizer,
    max_length=MAX_SEQ_LEN,
)

train_dataloader = DataLoader(
    train_dataset,
    shuffle=True,
    batch_size=TRAIN_BATCH_SIZE,
)
eval_dataloader = DataLoader(val_dataset, batch_size=TEST_BATCH_SIZE)

# %%
# train_dataset[2]
# val_dataset[2]

# %% [markdown]
# ### Step 3. Training

# %%
device = torch.device("cuda") if torch.cuda.is_available() else torch.device(
    "cpu")
model = AutoModelForSequenceClassification.from_pretrained(
    MODEL_NAME,
    num_labels=len(LABEL2ID),
)
model.to(device)

optimizer = AdamW(model.parameters(), lr=LR)
num_training_steps = NUM_EPOCHS * len(train_dataloader)
lr_scheduler = set_lr_scheduler(optimizer, num_training_steps)

writer = SummaryWriter(LOG_DIR)
# Out:
# Some weights of the model checkpoint at bert-base-chinese were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.predictions.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-chinese and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# Training (30 mins)

# %%
progress_bar = tqdm(range(num_training_steps))
current_steps = 0

for epoch in range(NUM_EPOCHS):
    model.train()

    for batch in train_dataloader:
        batch = {k: v.to(device) for k, v in batch.items()}
        outputs = model(**batch)
        loss = outputs.loss
        loss.backward()

        optimizer.step()
        lr_scheduler.step()
        optimizer.zero_grad()
        progress_bar.update(1)
        writer.add_scalar("training_loss", loss.item(), current_steps)

        y_pred = torch.argmax(outputs.logits, dim=1).tolist()
        y_true = batch["labels"].tolist()

        current_steps += 1

        if current_steps % VALIDATION_STEP == 0 and current_steps > 0:
            print("Start validation")
            val_results = run_evaluation(model, eval_dataloader, device)

            # log each metric separately to TensorBoard
            for metric_name, metric_value in val_results.items():
                print(f"{metric_name}: {metric_value}")
                writer.add_scalar(f"{metric_name}", metric_value, current_steps)

            save_checkpoint(
                model,
                CKPT_DIR,
                current_steps,
                mark=f"val_acc={val_results['val_acc']:.4f}",
            )

print("Finished training!")

# %%
#if <

# %% [markdown]
# ### Step 4. Make your submission

# %%
OUTPUT_FILENAME = "submission.jsonl" #@param {type:"string"}


#### 存檔名稱

# %%
### 選 Part 2 出來的資料集
TEST_DATA = load_json("data/test_doc5sent5_data3.jsonl") #@param {type:"string"}

### 蛤
TEST_PKL_FILE = Path("data/test_doc5sent5.pkl")

# %%
if not TEST_PKL_FILE.exists():
    test_df = join_with_topk_evidence(
        pd.DataFrame(TEST_DATA),
        mapping,
        mode="eval",
        topk=EVIDENCE_TOPK,
    )
    test_df.to_pickle(TEST_PKL_FILE, protocol=4)
else:
    with open(TEST_PKL_FILE, "rb") as f:
        test_df = pickle.load(f)

test_dataset = AicupTopkEvidenceBERTDataset(
    test_df,
    tokenizer=tokenizer,
    max_length=MAX_SEQ_LEN,
)
test_dataloader = DataLoader(test_dataset, batch_size=TEST_BATCH_SIZE)

# %%
print(test_df.shape)
test_df.head()

# %%
print(test_df.iloc[0]["evidence_list"])
print(len(test_df.iloc[0]["evidence_list"]))
# Out:
# ['顯微鏡泛指將微小不可見或難見物品之影像放大 ， 而能被肉眼或其他成像儀器觀察之工具 。', '光學顯微鏡 （ Optical microscope 、 Light microscope ） 是一種利用光學透鏡產生影像放大效應的顯微鏡 。', '十八世紀 ， 光學顯微鏡的放大倍率已經提高到了1000倍 ， 使人們能用眼睛看清微生物體的形態 、 大小和一些內部結構 。', '在量測或觀察上 ， 肉眼是指在沒有配合光學儀器 （ 如望遠鏡或顯微鏡 ） 的情形下進行的視覺觀察或檢測 。', '光學顯微鏡依其聚光鏡 （ condenser ） 和物鏡 （ Objective ） 的設計 ， 可用來觀察不同的樣品 。']
# 5

# %% [markdown]
# Prediction

# %%
### 選Model的路徑

CKPT_DIR="checkpoints/claim_verification/e20_bs32_7e-05_top5" #@param {type:"string"}

### 可以配合 ls 選Model

# %%
ls "checkpoints/claim_verification/e20_bs32_7e-05_top5"
# Out:
# 'val_acc=0.4043_model.25.pt'   'val_acc=0.5302_model.100.pt'
# 'val_acc=0.4055_model.50.pt'   'val_acc=0.5340_model.175.pt'
# 'val_acc=0.4181_model.125.pt'  'val_acc=0.5340_model.225.pt'
# 'val_acc=0.4194_model.100.pt'  'val_acc=0.5353_model.125.pt'
# 'val_acc=0.4259_model.750.pt'  'val_acc=0.5441_model.50.pt'
# 'val_acc=0.4295_model.75.pt'   'val_acc=0.5441_model.75.pt'
# 'val_acc=0.4773_model.25.pt'   'val_acc=0.5453_model.200.pt'
# 'val_acc=0.5088_model.150.pt'  'val_acc=0.5466_model.150.pt'

# %%
### 選Model名稱與 Testing

ckpt_name = "val_acc=0.5466_model.150.pt"  #@param {type:"string"}
model = load_model(model, ckpt_name, CKPT_DIR)
predicted_label = run_predict(model, test_dataloader, device)
# Out:
# Predicting:   0%|          | 0/62 [00:00<?, ?it/s]

# %%
### 存Testing檔

predict_dataset = test_df.copy()
predict_dataset["predicted_label"] = list(map(ID2LABEL.get, predicted_label))
predict_dataset[["id", "predicted_label", "predicted_evidence"]].to_json(
    OUTPUT_FILENAME+"_data3",
    orient="records",
    lines=True,
    force_ascii=False,
)

# %% [markdown]
# ### Step 5. XGBoost (先略過)

# %%
# !pip install sentence_transformers
from sentence_transformers import SentenceTransformer
import numpy as np

# %%
### for XGBoost
from sklearn.decomposition import PCA

def Prepare_XGBoost_Data(dataframe):
    """做資料"""

    concate=[]

    for i in range(dataframe.shape[0]):
      data="[CLS] "+dataframe["claim"][i]+" [SEP] "+dataframe["evidence_list"][i]
      concate.append(data)
      
    dataframe["concate"]=concate


def Go_Through_SBERT(dataframe,dimention): 
    """做資料"""
    # Load a pre-trained Chinese SBERT model
    model = SentenceTransformer('bert-base-chinese')    
    sentences=dataframe["concate"]
    embeddings = model.encode(sentences)

    # return embeddings,np.array(dataframe["label"])

    pca = PCA(n_components=dimention)
    embeddings_reduced = pca.fit_transform(embeddings)

    return embeddings_reduced , np.array(dataframe["label"])

def Go_Through_SBERT_test(dataframe): 
    """做資料"""
    # Load a pre-trained Chinese SBERT model
    model = SentenceTransformer('bert-base-chinese')    
    sentences=dataframe["concate"]
    embeddings = model.encode(sentences)

    return embeddings

# %%
if not TRAIN_PKL_FILE.exists():
    train_df = join_with_topk_evidence(
        pd.DataFrame(TRAIN_DATA),
        mapping,
        topk=EVIDENCE_TOPK,
    )
    train_df.to_pickle(TRAIN_PKL_FILE, protocol=4)
else:
    with open(TRAIN_PKL_FILE, "rb") as f:
        train_df = pickle.load(f)

if not DEV_PKL_FILE.exists():
    dev_df = join_with_topk_evidence(
        pd.DataFrame(DEV_DATA),
        mapping,
        mode="eval",
        topk=EVIDENCE_TOPK,
    )
    dev_df.to_pickle(DEV_PKL_FILE, protocol=4)
else:
    with open(DEV_PKL_FILE, "rb") as f:
        dev_df = pickle.load(f)

### 其中train_df的"evidence_list"會合併為一句
### dev_df不會，會是[top_n句]

# %%
print(train_df.shape)
print(dev_df.shape)
# Out:
# (3175, 7)
# (794, 7)

# %%
result = train_df["evidence_list"].map(lambda x: x[0])
train_df["evidence_list"]=result
train_df.head()["evidence_list"]
# Out:
# 0
# 1                   真靈長大目是用於取代靈長大目 （ Archonta ） 而成立的 。
# 2    目前 ， 商業智慧通常被理解爲將企業中現有的資料轉化爲知識 ， 幫助企業做出明智的業務經營決...
# 3       臺北市私立新民國民小學 ， 簡稱新民國小 ， 是一所在1956年所由蕭運貞創立的私立小學 。
# 4    雄性雉雞的羽毛非常多樣 ， 從幾乎白色到幾乎黑色都有 ， 這是由於馴化及與綠雉雜交 ， 加上...
# Name: evidence_list, dtype: object

# %%
### Make Piece of XGBoost data

Prepare_XGBoost_Data(train_df)

train_df.head()
###
# Out:
#      id            label                                              claim  \
# 0  3771  NOT ENOUGH INFO  殭屍可以用火來烹調、生熱、產生訊號及照明等，但也有火的負面影響，是影響全球生態系統的重要因素之一。
# 1  6391          refutes                                靈長大目與真靈長大目是並存的兩個分類。
# 2  8159         supports                  BI是協助組織制訂出最佳的策略主題與策略目標的一種決策支援的工具。
# 3  7670          refutes                                  臺北市私立新民國民小學是一所學校。
# 4  2680          refutes                 雄性雉雞由於馴化、互交的結果，羽毛非常多樣，雌雉雞則在各大陸差異小。
#
#                                             evidence  \
# 0                       [[[3237, None, None, None]]]
# 1                         [[[6635, 6392, 真靈長大目, 3]]]
# 2  [[[7323, 6958, 商業智能, 7], [7323, 6958, 商業智能, 17]]]
# 3                   [[[6976, 6660, 臺北市私立新民國民小學, 0]]]
# 4                            [[[4306, 4417, 雉雞, 1]]]
#
#             predicted_pages  \
# 0                [殭屍, 熱, 火]
# 1     [靈長大目, 真靈長大目, 目_(生物)]
# 2  [BI_253, 組織, BI, 工具, 決策]
# 3    [臺北市, 臺北市私立新民國民小學, 學校]
# 4         [羽毛, 雉雞, 差異_(哲學)]
#
#                                   predicted_evidence  \
# 0       [[火, 15], [火, 16], [火, 17], [火, 12], [火, 8]]
# 1  [[真靈長大目, 0], [靈長大目, 0], [真靈長大目, 3], [靈長大目, 16]...
# 2  [[BI_253, 1], [工具, 6], [組織, 0], [BI_253, 0], [...
# 3  [[臺北市私立新民國民小學, 0], [臺北市私立新民國民小學, 2], [臺北市私立新民國...
# 4      [[雉雞, 1], [雉雞, 2], [雉雞, 0], [羽毛, 1], [羽毛, 2]]
#
#                                        evidence_list  \
# 0
# 1                 真靈長大目是用於取代靈長大目 （ Archonta ） 而成立的 。
# 2  目前 ， 商業智慧通常被理解爲將企業中現有的資料轉化爲知識 ， 幫助企業做出明智的業務經營決...
# 3     臺北市私立新民國民小學 ， 簡稱新民國小 ， 是一所在1956年所由蕭運貞創立的私立小學 。
# 4  雄性雉雞的羽毛非常多樣 ， 從幾乎白色到幾乎黑色都有 ， 這是由於馴化及與綠雉雜交 ， 加上...
#
#                                              concate
# 0  [CLS] 殭屍可以用火來烹調、生熱、產生訊號及照明等，但也有火的負面影響，是影響全球生態系...
# 1  [CLS] 靈長大目與真靈長大目是並存的兩個分類。 [SEP] 真靈長大目是用於取代靈長大目...
# 2  [CLS] BI是協助組織制訂出最佳的策略主題與策略目標的一種決策支援的工具。 [SEP] ...
# 3  [CLS] 臺北市私立新民國民小學是一所學校。 [SEP] 臺北市私立新民國民小學 ， 簡稱...
# 4  [CLS] 雄性雉雞由於馴化、互交的結果，羽毛非常多樣，雌雉雞則在各大陸差異小。 [SEP]...

# %%
### Make Piece of XGBoost data

new_df=train_df.iloc[:].reset_index(drop=True)


X_train,Y_train=Go_Through_SBERT(new_df,350)
print(type(X_train),type(Y_train))
print(X_train.shape,Y_train.shape)
Sbert_df=pd.DataFrame(X_train)

print(X_train[0,:10])

###
# Out:
# Downloading (…)5ee55/.gitattributes:   0%|          | 0.00/445 [00:00<?, ?B/s]
# Downloading (…)92f8d5ee55/README.md:   0%|          | 0.00/1.85k [00:00<?, ?B/s]
# Downloading (…)f8d5ee55/config.json:   0%|          | 0.00/624 [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/412M [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/412M [00:00<?, ?B/s]
# Downloading (…)5ee55/tokenizer.json:   0%|          | 0.00/269k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading (…)92f8d5ee55/vocab.txt:   0%|          | 0.00/110k [00:00<?, ?B/s]
# WARNING:sentence_transformers.SentenceTransformer:No sentence-transformers model found with name /root/.cache/torch/sentence_transformers/bert-base-chinese. Creating a new one with MEAN pooling.
# Some weights of the model checkpoint at /root/.cache/torch/sentence_transformers/bert-base-chinese were not used when initializing BertModel: ['cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# <class 'numpy.ndarray'> <class 'numpy.ndarray'>
# (3175, 350) (3175,)
# [ 0.6327243   2.8292928  -0.04243648 -0.05682664 -0.29191715 -0.8225097
#  -0.27499047  0.25851    -1.4781861  -1.1007603 ]

# %%
print(train_df["label"].unique())
# Out:
# ['NOT ENOUGH INFO' 'refutes' 'supports']

# %%
temp_y=pd.Series(Y_train)
temp_y=temp_y.map({'NOT ENOUGH INFO':0,'refutes':1,'supports':2})
# print(temp_y[:20])
temp_y.to_csv("Part_3_trainning_3_y.csv")

Y_train=temp_y.values

# %%
print(Y_train)
# Out:
# [0 1 2 ... 1 0 2]

# %%
### Make Piece of XGBoost data

Sbert_df.to_csv("Part_3_trainning_3_x.csv")

###

# %%
from xgboost import XGBClassifier

# 建立XGBClassifier模型
xgboostModel = XGBClassifier(n_estimators=150, learning_rate= 0.2,max_depth=5) #max_depth
# 使用訓練資料訓練模型
xgboostModel.fit(X_train, Y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.2, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=150, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...)

# %%
print('訓練集: ',xgboostModel.score(X_train,Y_train))
# Out:
# 訓練集:  1.0

# %%
dev_df.iloc[2]["evidence_list"]
# Out:
# ['李賦寧  ， 男 ， 祖籍陝西蒲城 ， 生於江蘇南京 ， 中國教育家 、 翻譯家 。',
#  '癌症在發達國家中已成爲主要死亡原因之一 ， 在臺灣則是長年位居十大死因之首 。',
#  '美國每年逝世的5個人當中有一人是因癌症致死 ， 這一數字在世界範圍則是100 - 350 / 100000 。',
#  '約5 - 10 % 的癌症是由於遺傳自雙親的基因異常 。',
#  '癌症 （ 英語 ： Cancer ） ， 又名爲惡性腫瘤 （ 英語 ： Malignant tumor ） ， 中醫學中稱癌 、 瘤 ， 指的是細胞不正常增生 ， 且這些增生的細胞可能侵犯身體的其他部分 ， 爲由控制細胞分裂增殖機制失常而引起的疾病 。']

# %%
result = dev_df["evidence_list"].map(lambda x: " ".join(x))
dev_df["evidence_list"]=result
# dev_df.head()["evidence_list"]
print(dev_df.iloc[:10]["evidence_list"].values)
# Out:
# ['護照或護證  是一個國家或地區的政府發放給本國公民或國民的一種旅行證件 ， 用於證明持有人的身分與國籍 ， 以便其出入本國及在外國旅行 ， 同時亦用於請求有關外國當局給予持照人通行便利及保護 。 某些情況下 ， 一個國家政府也可給外國籍人士發放護照 ， 如 “ 葡萄牙給外國人護照 ” 。 旅行證件通常爲小冊子形式 ， 以允許其他政府 （ 司法管轄區 ） 發放簽證以及 。 旅行證件有時並不用於證明國籍 ， 如難民旅行證 。 旅行證件通常向其他政府保證 ： 持證人可以返回發證國 。'
#  'ILGA現在擁有超過1100個團體會員 ， 分佈在六大地區的110多個國家 ， 組織願景爲確保任何人不分其性傾向 、 性別認同 、 性別表達和性徵 ， 都能享有自由平等的人權 ， 並致力於實現這樣一種全球正義和平權的世界 。 國際LGBTI聯合會 （ International Lesbian , Gay , Bisexual , Trans and Intersex Association ） 是一個促進世界各地區女同性戀 、 男同性戀 、 雙性戀 、 跨性別和雙性人群體共同爭取平權的國際組織 。 該組織於1978年成立 ， 爲國際同性戀聯合會 （ International Gay Association ， IGA ） ， 在1986年改名爲國際男女同性戀聯合會 （ International Lesbian and Gay Association ， ILGA ） 。 目標可以是短期的 ， 也可以是長期的 。 目標是個人或組織在某種理想狀態下希望達到的狀態 。'
#  '李賦寧  ， 男 ， 祖籍陝西蒲城 ， 生於江蘇南京 ， 中國教育家 、 翻譯家 。 癌症在發達國家中已成爲主要死亡原因之一 ， 在臺灣則是長年位居十大死因之首 。 美國每年逝世的5個人當中有一人是因癌症致死 ， 這一數字在世界範圍則是100 - 350 / 100000 。 約5 - 10 % 的癌症是由於遺傳自雙親的基因異常 。 癌症 （ 英語 ： Cancer ） ， 又名爲惡性腫瘤 （ 英語 ： Malignant tumor ） ， 中醫學中稱癌 、 瘤 ， 指的是細胞不正常增生 ， 且這些增生的細胞可能侵犯身體的其他部分 ， 爲由控制細胞分裂增殖機制失常而引起的疾病 。'
#  "“ Aion ” ， 第五張專輯 ， 於1990年出版 ， 這張專輯顯示出樂隊對中近東音樂元素的注意與興趣 。 “ Within the Realm of a Dying Sun ” ， 樂隊的第三張專輯 ， 於1986年出版 。 第四張專輯 ， “ The Serpent 's Egg ” ， 則於1988年面世 ， 與上一張作品的肅穆的哥特風格相比 ， 這張專輯受拜占庭宗教音樂的影響 ， 旋律莊嚴而緩慢 。 爲了進一步開拓美國市場 ， 樂隊於1991年發表精選專輯 “ A Passage in Time ” ， 這是樂隊第一張進入美國市場的作品 。 第二張專輯 ， “ Spleen and Ideal ” 於1985年推出 ， 這張專輯標誌着樂隊初步探索出其日後的主要風格 ， 即將歐洲民俗音樂 — — 特別是帶有中世紀與文藝復興時期色彩的 — — 與氛圍流行樂 （ Ambient Pop ） 結合 ， 營造出一種迷離的宗教氣氛與富於異國情調的旋律 。"
#  '她嫁給西風神則費羅斯 （ Zephyrus ） 並生了三個孩子 ， 分別是 ： Ampyx 、 Mopsus和Carpus 。 Neleus的妻子名爲克洛莉絲 ， 她是Nestor 、 Pero和Alastor的母親 。 克洛里斯 （ 亦稱 “ greenish ” ） 是春天 、 花卉和自然女神 。 Meliboea是尼俄伯 （ Niobe ） 的女兒 ， 是被阿爾忒彌斯和阿波羅殺死的尼俄伯家 （ Niobids ） 唯一的倖存者 。 Poriclymenus的母親 （ 父親是海神波塞冬 ） 。'
#  '吉林大學 （ Jilin University ， 縮寫 ： JLU ） ， 簡稱吉大 ， 位於中國吉林省長春市 ， 是中國共產黨領導創建的第一所綜合性高等學府 ， 是中華人民共和國教育部直屬的全國重點大學 ， 中國東北地區重點建設的一所綜合性大學 。 吉林大學是 “ 雙一流A類 ” 和原 “ 985工程 ” 、 原 “ 211工程 ” 重點建設大學 ， 同時也是國家首批 “ 珠峯計劃 ” 、 “ 111計劃 ” 、 “ 卓越計劃 ” 和 “ 2011計劃 ” 重點建設的名牌大學 。 | 機構名稱 = 中華人民共和國教育部 吉林市 ， 滿語名爲吉林烏拉 （ -LSB- ᡤᡳᡵᡳᠨᡠᠯᠠ , v = girin ula , a = girin ula -RSB- ， 意爲 “ 沿江 ” ） ， 別稱 “ 北國江城 ” ， 是中華人民共和國吉林省下轄的地級市 ， 國務院批准的較大的市 ， 爲吉林省第二大城市 ， 原吉林省省會 ， 位於吉林省中部偏東 。 中華人民共和國教育部 ， 中華人民共和國主管教育行政事務的國務院組成部門 。'
#  '因北方遊牧民族發動戰爭 ， 晉懷帝與晉愍帝先後被俘殺 ， 琅琊王司馬睿在群臣擁戴下在建康 （ 今南京 ） 即位 ， 即晉元帝 ， 史稱東晉 。 因江東被晉人視爲東方 ， 因而司馬睿之後的晉朝被劉宋稱作東晉 。 東晉 （ 317年4月6日 － 420年7月10日 ） ， 中國朝代 ， 乃西晉司馬氏政權的延續 。 東晉雖然是司馬氏政權的延續 ， 但司馬氏在政治上威望不高 ， 朝廷由世族大家把持 ， 最先的一個乃出身琅琊王氏的王導 ， 其後又有陳郡謝氏的謝安 、 謝玄等等 。 皇帝 （ Regal Imperium ） ， 意指帝國的國家元首 ， 是一類在東西方各國的統治者中佔據最高位置君主的頭銜 。'
#  '香港科技大學創立於1991年 ， 是香港第三所獲得大學名銜的學府 。 香港科技大學是香港最頂尖的大學之一 ， 現時屬於 「 QS世界百強大學 」 及 「 泰晤士高等教育世界百強大學 」 ， 是香港乃至亞洲一所較爲年輕但表現強勁的高等學府 。 香港科技大學 （ The Hong Kong University of Science and Technology ， 縮寫 ： HKUST ） ， 簡稱科大 ， 是香港的一所公立研究型大學 ， 位於香港新界西貢區清水灣半島 。 科大建校僅三十年 ， 現已成爲亞洲以至全球領先的研究學府之一 ， 被認爲是世界上發展最快的大學之一 。 香港科技大學現時設有四所學術學院 、 一個跨學科課程事務處和兩個研究院 ， 涉及科學 、 工程 、 商業教育 、 人文和社會科學等不同範疇 。'
#  '吠陀 （ -LSB- वेद , ， 又譯爲韋達經 、 韋陀經 、 圍陀經等 ） ， 是婆羅門教和現代的印度教最重要和最根本的經典 。 印度最重要的貿易伙伴是美國 、 歐盟 、 日本 、 中華人民共和國 、 俄羅斯 、 阿拉伯聯合酋長國 。 近年來 ， 印度政府還大力投資本國高等教育 ， 以利於在科學上與國際接軌 ， 例如自主太空研究 、 南亞半島生態研究等等 。 以耕種農業 、 城市手工業 、 服務業以及其支撐產業爲主的部分行業已經相對取得了進展 。 同時印度還是很多專利過期藥物的生產地 ， 以低價格提供可靠的醫療 。'
#  '受中亞與西亞中伊斯蘭教傳播的影響 ， 許多回族成爲穆斯林 ， 伊斯蘭教被稱爲回教 。 回族 （ 小兒經 ： ； 漢語拼音 ： ） ， 中國民族之一 ， 族名來自唐朝回鶻 ， 古代又稱回回或畏兀兒 ， 世居於黃河流域西北地帶 ， 由內蒙古至山西 、 陝西 、 甘肅 ， 以至於新疆和中亞一帶 ， 先祖主要爲突厥人 ， 但混有蒙古人 、 波斯人 、 大月氏 、 塞種人 、 粟特人 、 阿拉伯人 ， 以至於羌族與漢族等不同血統 。 蒙古帝國時 ， 以突厥人爲主的中亞 、 西亞色目人 ， 皆被統稱爲回回 ， 居住在黃河西北地帶的突厥部落也被包括在其中 。 至中華人民共和國成立後 ， 回族成爲官方認定的十個信仰伊斯蘭教的少數民族之一 ， 其族群則限縮爲通用漢語 ， 居住在中國內地各省份的居民 ， 與維吾爾族 ， 保安族等分開 。 也因此 ， 在元代之後 ， 由新疆至中國南方 ， 所有穆斯林群體 ， 不分血統 ， 都被稱爲回族 ， 回族因此遍佈全中國 。']

# %%
### Make Piece of XGBoost data

Prepare_XGBoost_Data(dev_df)

dev_df.head()
###
# Out:
#      id            label                                              claim  \
# 0  7104         supports  屬於旅行證件的護照可用於請求有關外國當局給予持照人交通安全及保護，而國家政府也可給外國籍人士...
# 1  5550  NOT ENOUGH INFO                       國際LGBTI聯合會的組織願景從建立到現在只有一個目標。
# 2  8741  NOT ENOUGH INFO                                     中國教育家李賦寧死因是癌症。
# 3  4620         supports                        「Aion」是死者能舞的第五張專輯，於1990年出版。
# 4  9099         supports                                   克洛里斯是西風之神費羅斯的妻子。
#
#                                            evidence  \
# 0      [[[6104, 5950, 護照, 0], [6104, 5950, 護照, 1]]]
# 1                      [[[5576, None, None, None]]]
# 2                      [[[7839, None, None, None]]]
# 3                        [[[3222, 3386, 死者能舞, 18]]]
# 4  [[[8132, 7629, 克洛里斯, 2], [8132, 7629, 克洛里斯, 3]]]
#
#                       predicted_pages  \
# 0               [人, 旅行證件, 政府, 安全, 護照]
# 1                [目標, 國際LGBTI聯合會, 現在]
# 2                  [教育家, 李賦寧, 癌症, 中國]
# 3                       [死者能舞, 1990年]
# 4  [克洛里斯, 雨果·洛里斯, 神, 洛里斯_(沃克呂茲省), 妻子]
#
#                                   predicted_evidence  \
# 0  [[護照, 0], [護照, 1], [旅行證件, 2], [旅行證件, 9], [旅行證件...
# 1  [[國際LGBTI聯合會, 2], [國際LGBTI聯合會, 0], [國際LGBTI聯合會...
# 2  [[李賦寧, 0], [癌症, 42], [癌症, 41], [癌症, 11], [癌症, 0]]
# 3  [[死者能舞, 18], [死者能舞, 11], [死者能舞, 14], [死者能舞, 20...
# 4  [[克洛里斯, 3], [克洛里斯, 11], [克洛里斯, 2], [克洛里斯, 7], ...
#
#                                        evidence_list  \
# 0  護照或護證  是一個國家或地區的政府發放給本國公民或國民的一種旅行證件 ， 用於證明持有人的...
# 1  ILGA現在擁有超過1100個團體會員 ， 分佈在六大地區的110多個國家 ， 組織願景爲確...
# 2  李賦寧  ， 男 ， 祖籍陝西蒲城 ， 生於江蘇南京 ， 中國教育家 、 翻譯家 。 癌症在...
# 3  “ Aion ” ， 第五張專輯 ， 於1990年出版 ， 這張專輯顯示出樂隊對中近東音樂元...
# 4  她嫁給西風神則費羅斯 （ Zephyrus ） 並生了三個孩子 ， 分別是 ： Ampyx ...
#
#                                              concate
# 0  [CLS] 屬於旅行證件的護照可用於請求有關外國當局給予持照人交通安全及保護，而國家政府也可...
# 1  [CLS] 國際LGBTI聯合會的組織願景從建立到現在只有一個目標。 [SEP] ILGA現...
# 2  [CLS] 中國教育家李賦寧死因是癌症。 [SEP] 李賦寧  ， 男 ， 祖籍陝西蒲城 ，...
# 3  [CLS] 「Aion」是死者能舞的第五張專輯，於1990年出版。 [SEP] “ Aion...
# 4  [CLS] 克洛里斯是西風之神費羅斯的妻子。 [SEP] 她嫁給西風神則費羅斯 （ Zeph...

# %%
### Make Piece of XGBoost data

new_df=dev_df.iloc[:].reset_index(drop=True)


X_test,Y_test=Go_Through_SBERT(new_df,350)
print(X_test.shape,Y_test.shape)
Sbert_df=pd.DataFrame(X_test)

print(X_test[0,:10])

###
# Out:
# WARNING:sentence_transformers.SentenceTransformer:No sentence-transformers model found with name /root/.cache/torch/sentence_transformers/bert-base-chinese. Creating a new one with MEAN pooling.
# Some weights of the model checkpoint at /root/.cache/torch/sentence_transformers/bert-base-chinese were not used when initializing BertModel: ['cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# (794, 350) (794,)
# [ 0.2436698   1.3171079  -1.0007699   0.24592383 -0.56124336  0.36128232
#  -1.0755689  -0.25118673 -1.2161074  -0.61315405]

# %%
temp_y=pd.Series(Y_test)
temp_y=temp_y.map({'NOT ENOUGH INFO':0,'refutes':1,'supports':2})
# print(temp_y[:20])
temp_y.to_csv("Part_3_testing_3_y.csv")

Y_test=temp_y.values

# %%
### Make Piece of XGBoost data

Sbert_df.to_csv("Part_3_testing_3_x.csv")

###

# %%
print('訓練集: ',xgboostModel.score(X_test,Y_test))
# Out:
# 訓練集:  0.38287153652392947

# %%
from xgboost import XGBClassifier
import pickle

best_n_tree=0
best_max_depth=0
best_model="None"
best_test_acc = 0.43

for n_tree in [25,30,40,45,50,75,100,110,125,150,180,210]:
  for depth in [3,4,5,6,7,8]:
    xgboostModel = XGBClassifier(n_estimators=n_tree, learning_rate= 0.2,max_depth=depth) #max_depth
    xgboostModel.fit(X_train, Y_train)

    test_score=xgboostModel.score(X_test,Y_test)

    print('Train: ',xgboostModel.score(X_train,Y_train),' Test: ',test_score, " With n_tree=",n_tree," ;depth=",depth,end="   ")

    if test_score > best_test_acc:
      best_model=xgboostModel
      best_n_tree=n_tree
      best_max_depth=depth
      best_test_acc=test_score
      print("[ New Record ]",end=" ")
      with open('xgboost_model_'+str(n_tree)+'_'+str(depth)+'.pkl', 'wb') as f:
        pickle.dump(xgboostModel, f)
    

    print("")

print("\n\nBest model:")
print("Best n_tree : ", best_n_tree)
print("Best max_depth : ", best_max_depth)

# %%
pwd
# Out:
# '/content/drive/MyDrive/NCKU-AICUP2023-baseline'

# %%
# !ls | grep pkl
# Out:
# xgboost_model_100_5.pkl
# xgboost_model_100_9.pkl
# xgboost_model_125_5.pkl
# xgboost_model_150_5.pkl
# xgboost_model_25_3.pkl
# xgboost_model_25_4.pkl
# xgboost_model_30_4.pkl
# xgboost_model_40_5.pkl
# xgboost_model_50_3.pkl
# xgboost_model_50_4.pkl
# xgboost_model_50_5.pkl
# xgboost_model_50_6.pkl
# xgboost_model_50_7.pkl
# xgboost_model_50_9.pkl
# xgboost_model_75_5.pkl

# %%
# 載入模型

import pickle

with open('xgboost_model_40_5.pkl', 'rb') as f:
    xgboostModel = pickle.load(f)

# %%
print(test_df.iloc[0]["evidence_list"].values)
test_df.head()
# Out:
# 顯微鏡泛指將微小不可見或難見物品之影像放大 ， 而能被肉眼或其他成像儀器觀察之工具 。 光學顯微鏡 （ Optical microscope 、 Light microscope ） 是一種利用光學透鏡產生影像放大效應的顯微鏡 。 十八世紀 ， 光學顯微鏡的放大倍率已經提高到了1000倍 ， 使人們能用眼睛看清微生物體的形態 、 大小和一些內部結構 。 光學顯微鏡依其聚光鏡 （ condenser ） 和物鏡 （ Objective ） 的設計 ， 可用來觀察不同的樣品 。 由物體入射的光被至少兩個光學系統 （ 物鏡和目鏡 ） 放大 。 最常見的 （ 和第一個被髮明的 ） 是光學顯微鏡 ， 其他主要的顯微鏡類型包括電子顯微鏡 、 掃描探針顯微鏡等 。 光學顯微鏡依樣品的不同可分爲反射式和透射式 。 這種顯微鏡常被用來觀察生物組織 。
#      id                                claim          predicted_pages  \
# 0  5208  光學顯微鏡是以電磁學原理來將不可見或難見的微小物放大至肉眼可見的儀器。        [顯微鏡, 電磁學, 光學顯微鏡]
# 1  1019              產絲的蠶或產蜜的蜜蜂爲提供間接經濟利益的昆蟲。                     [昆蟲]
# 2  8514              波蘭西部的綠山城縣平均每平方公里的土地有0人。       [綠山城縣, 綠山城, 0, 波蘭]
# 3  1874             Vivien Leigh主演魂斷藍橋中的女配角。   [藍橋_(阿姆斯特丹), 藍橋, 魂斷藍橋]
# 4  8352          侯孝賢改編自唐代文言文學的電影獲得金馬獎最佳劇情片獎。  [文言文, 侯孝賢, 金馬獎, 文學, 電影]
#
#                                   predicted_evidence  \
# 0  [[顯微鏡, 0], [光學顯微鏡, 0], [光學顯微鏡, 9], [光學顯微鏡, 22]...
# 1  [[昆蟲, 22], [昆蟲, 23], [昆蟲, 25], [昆蟲, 15], [昆蟲, ...
# 2  [[綠山城, 0], [綠山城縣, 0], [波蘭, 1], [綠山城, 7], [0, 2...
# 3  [[魂斷藍橋, 0], [藍橋, 2], [魂斷藍橋, 7], [魂斷藍橋, 4], [藍橋...
# 4  [[侯孝賢, 2], [侯孝賢, 1], [侯孝賢, 3], [侯孝賢, 0], [金馬獎,...
#
#                                        evidence_list
# 0  顯微鏡泛指將微小不可見或難見物品之影像放大 ， 而能被肉眼或其他成像儀器觀察之工具 。 光學...
# 1  許多昆蟲被認爲是對生態有益的捕食者 ， 少數昆蟲提供直接的經濟利益 。 蠶產絲 ， 蜜蜂產蜂...
# 2  綠山城 （ 波蘭語 ： ； 德語 ： ， 西里西亞的格呂恩貝格 ） 是位於波蘭西部的城市 ，...
# 3  《 魂斷藍橋 》 （ Waterloo Bridge ） 是美國黑白電影 ， 由米高梅電影公...
# 4  2015年以 《 刺客聶隱娘 》 獲得第68屆坎城影展最佳導演獎及第52屆金馬獎最佳導演獎與...

# %%
result = test_df["evidence_list"].map(lambda x: " ".join(x))
test_df["evidence_list"]=result
# dev_df.head()["evidence_list"]
print(test_df.iloc[:10]["evidence_list"].values)
# Out:
# ['顯微鏡泛指將微小不可見或難見物品之影像放大 ， 而能被肉眼或其他成像儀器觀察之工具 。 光學顯微鏡 （ Optical microscope 、 Light microscope ） 是一種利用光學透鏡產生影像放大效應的顯微鏡 。 十八世紀 ， 光學顯微鏡的放大倍率已經提高到了1000倍 ， 使人們能用眼睛看清微生物體的形態 、 大小和一些內部結構 。 光學顯微鏡依其聚光鏡 （ condenser ） 和物鏡 （ Objective ） 的設計 ， 可用來觀察不同的樣品 。 由物體入射的光被至少兩個光學系統 （ 物鏡和目鏡 ） 放大 。 最常見的 （ 和第一個被髮明的 ） 是光學顯微鏡 ， 其他主要的顯微鏡類型包括電子顯微鏡 、 掃描探針顯微鏡等 。 光學顯微鏡依樣品的不同可分爲反射式和透射式 。 這種顯微鏡常被用來觀察生物組織 。'
#  '許多昆蟲被認爲是對生態有益的捕食者 ， 少數昆蟲提供直接的經濟利益 。 蠶產絲 ， 蜜蜂產蜂蜜 ， 兩者都已被人類馴化 。 在東南亞和南美的一些地方 ， 昆蟲本身就是當地人的食品 。 這層殼會分節以利於運動 ， 猶如騎士的甲冑 。 昆蟲在生態扮演着很重要的角色 。 昆蟲是蜥蜴 、 青蛙 、 中小型鳥類等的重要食物來源 。 但昆蟲也可能對人類產生威脅 ， 如蝗蟲會破壞農作物 ， 白蟻破壞木材及建築物 。 蟲媒花需要得到昆蟲的幫助 ， 才能傳播花粉 。'
#  '綠山城 （ 波蘭語 ： ； 德語 ： ， 西里西亞的格呂恩貝格 ） 是位於波蘭西部的城市 ， 2019年時有 141,222 名居民 。 綠山城縣  ， 是波蘭的縣份 ， 位於該國西部 ， 由盧布斯卡省負責管轄 ， 首府設於綠山城 ， 面積 1,571 平方公里 ， 2006年人口 89,543 ， 人口密度每平方公里57人 。 波蘭國土面積 312,679 平方公里 ， 位居歐洲第十 ； 人口約 3,826 萬人 ， 位居歐洲第九 、 歐盟第五 。 綠山城自從1999年以來屬盧布斯卡省管轄 ， 原本是綠山城省 （ 1975 - 1998年 ） 首府 ， 現今則是盧布斯卡省的兩個省府之一 （ 另一個是大波蘭地區戈茹夫 ） 。 在數論中 ， 0不屬於自然數 ； 但在集合論和計算機科學中 ， 0屬於自然數 。 其北臨波羅的海 ， 西接德國 ， 西南接捷克 ， 南接斯洛伐克 ， 東南接烏克蘭 ， 東接白俄羅斯 ， 東北接立陶宛及俄羅斯加里寧格勒州 。 波蘭歷史悠久 ， 早在五十萬年前就有先民居住 。 0在整數 、 實數和其他的代數結構中都有著單位元這個很重要的性質 。'
#  '《 魂斷藍橋 》 （ Waterloo Bridge ） 是美國黑白電影 ， 由米高梅電影公司於1940年出品 ； 導演是茂文 · 李洛埃 （ Mervyn LeRoy ） ， 女主角是主演 《 亂世佳人 》 的費雯 · 麗 （ Vivien Leigh ） 而男主角是羅伯特 · 泰勒 （ Robert Taylor ） 。 美國電影Waterloo Bridge的中文譯名便是 《 魂斷藍橋 》 。 從此之後 ， 人們把相愛的男女一方失約 ， 而另一方殉情叫做 “ 魂斷藍橋 ” 。 原文片名意指 「 滑鐵盧橋 」 ， 中譯成 「 藍橋 」 點出 “ 尾生抱柱 ” 的故事 。 藍橋  是荷蘭阿姆斯特丹的一座橋樑 ， 位於阿姆斯特爾河上 。 男女愛情的約會往往稱之爲 “ 藍橋約 ” ， 若其中一方失約 ， 而另一方殉情則爲 “ 魂斷藍橋 ” 。 亦有一部粵劇以這個 「 魂斷藍橋 」 來命名 。 該橋連接了倫勃朗廣場和滑鐵盧廣場兩地 。'
#  '2015年以 《 刺客聶隱娘 》 獲得第68屆坎城影展最佳導演獎及第52屆金馬獎最佳導演獎與金馬獎最佳劇情片獎 。 曾榮獲三屆金馬獎最佳導演獎 ， 1989年的 《 悲情城市 》 獲得第46屆威尼斯影展金獅獎 ， 1993年憑藉 《 戲夢人生 》 獲得第46屆坎城影展評審團獎 。 2020年獲得第57屆金馬獎終身成就獎 。 侯孝賢是臺灣電影導演 ， 其電影在國內外各大重要影展獲得重大獎項 ， 爲臺灣新電影代表人物之一 。 金馬獎 （ 英語譯名 ： Golden Horse Awards ， 簡寫爲GHA ） 是臺灣的電影獎 ， 也是歷史最悠久的華語電影獎 ， 爲華語電影業界最具影響力與代表性的電影獎之一 ， 有 「 華語的奧斯卡金像獎 」 的美譽 。 這種方法可避免膠片長時間存放的失真 。 目前是臺灣電影文化協會榮譽理事長 。 | name = 金馬獎Golden Horse Awards'
#  '中共第十六 、 十七屆中央委員 ， 第十七屆中央政治局委員 ， 2012年9月被開除黨籍 。 但受王立軍事件影響 ， 2012年3月15日 ， 薄熙來被解除中共重慶市委書記職務 ， 同年4月10日被停止中共中央委員和政治局委員職務 ， 接受中共中央紀委調查 ， 並於同年9月28日被開除黨籍 、 公職並以其涉嫌犯罪問題及犯罪問題線索被移送司法機關處理 。 他是國務院前副總理薄一波的次子 。 薄熙來  ， 男 ， 山西定襄人 ， 生於北平 ， 中國共產黨和中華人民共和國政治家 ， 中國共產黨前主要領導人之一 。 同年10月26日 ， 薄熙來的第十一屆全國人大代表職務被重慶市人大常委會罷免 。 薄熙來歷任大連市市長 、 中共大連市委書記 、 遼寧省省長 ， 2004年進京任商務部部長 。 2013年7月25日 ， 濟南市人民檢察院向山東省濟南市中級人民法院就薄熙來涉嫌受賄 、 貪污 、 濫用職權一案提起公訴 ， 2013年8月22日法院開庭審理 ， 薄熙來否認受賄貪污 ， 法院一審9月22日判處無期徒刑 。 同日 ， 最高檢決定對薄熙來立案偵查並採取強制措施 。'
#  '最近發生的水星凌日 ： 2003年5月7日 、 2006年11月8日 、 2016年5月9日 、 2019年11月11日 。 水星凌日發生在五月初或十一月初 ， 平均每百年出現十三次水星凌日的現象 。 水星凌日是一種天文現象 。 目前在地球上可觀測到的凌日現象有金星凌日和水星凌日 ， 德國天文學家開普勒在1629年預言 ： “ 1631年11月7日將發生水星凌日 。 ” 火星上的水星凌日比地球上的水星凌日更爲罕見 ， 要數十年才發生一次 。 水星凌日是水星運行到太陽和火星之間時 ， 看見水星橫越過太陽前方的一種罕見天文現象 。 水星和金星可能會同時凌日 ， 但極爲罕見 。 迄今尚無人從火星上看見水星凌日 ， 但未來殖民火星的人類可以觀測到 。'
#  '馬克思主義政治經濟學 ， 也稱馬克思主義經濟學 ， 馬克思在其著作 《 資本論 》 中闡述了該學說的基本觀點 。 馬克思主義政治經濟學 ， 也稱馬克思主義經濟學 ， 馬克思在其著作 《 資本論 》 中闡述了該學說的基本觀點 。 馬克思研究了資本主義經濟學的理論和英國曆年的經濟統計資料 ， 對資本主義經濟學理論進行了分析和批判 。 馬克思研究了資本主義經濟學的理論和英國曆年的經濟統計資料 ， 對資本主義經濟學理論進行了分析和批判 。 車站的名稱取自紀念法國社會主義政治家的 。 車站的名稱取自紀念法國社會主義政治家的 。 其持續寫作 ， 並開始構建他關於社會經濟活動的理論 。 其持續寫作 ， 並開始構建他關於社會經濟活動的理論 。'
#  '該教的宇宙觀將人類歷史分成青陽 、 紅陽 、 白陽三期 ， 含有末劫救贖思想 ， 相信無極老母派遣彌勒佛 （ 轉世爲祖師路中一 ） 拯救凡間 。 一貫道信奉明明上帝 （ 俗稱無生老母 、 無極老母 ） 是創造天地者 ， 全名爲 「 明明上帝 無量清虛 至尊至聖 三界十方 萬靈真宰 」 ， 簡稱 「 道 」 ， 以 「 先天母字 」 符號象徵 ， 主張是 「 道 」 不是 「 教 」 。 亦禮敬濟公 （ 轉世爲祖師張天然 ） 、 南海古佛 、 關法律主 、 呂法律主 、 孔子 、 穆罕默德 、 耶穌等仙佛神聖 。 一貫道 （ 英語Yiguandao / I - Kuan Tao ； 漢語拼音 ： Yīguàn Dào ； 威妥瑪拼音 : I1 - Kuan4 Tao4 ） 是新興的中國民間宗教 ， 融合儒 、 釋 、 道 、 基督 、 回五教教義 ， 早期有借竅臨壇 、 開沙等類似於道教的扶乩等儀式 。 一貫道相信迴歸 「 道 」 是各宗教的共同目標 ， 「 道 」 也可以透過各種形式顯現 ， 故世上五大宗教儒 、 釋 、 道 、 耶 、 回其實是殊途同歸 ， 引用了禪宗 「 一花開五葉 」 的 「 五教同源 」 理論 。 早年的入道儀式頗具神祕色彩 ， 亦因此爲兩岸執政當局猜忌 。 一貫道道統溯源遙尊伏羲氏 、 黃帝 、 孔子 、 孟子 、 曾子等上古聖賢及釋迦牟尼佛 、 漢傳佛教達摩 、 惠能禪師等人爲其祖師 。 中華人民共和國成立後於1950年10月10日發佈 《 關於鎮壓反革命活動的指示 》 ， 開展鎮壓反革命運動 ， 一貫道在此期間被作爲會道門取締 。'
#  '回族 （ 小兒經 ： ； 漢語拼音 ： ） ， 中國民族之一 ， 族名來自唐朝回鶻 ， 古代又稱回回或畏兀兒 ， 世居於黃河流域西北地帶 ， 由內蒙古至山西 、 陝西 、 甘肅 ， 以至於新疆和中亞一帶 ， 先祖主要爲突厥人 ， 但混有蒙古人 、 波斯人 、 大月氏 、 塞種人 、 粟特人 、 阿拉伯人 ， 以至於羌族與漢族等不同血統 。 受中亞與西亞中伊斯蘭教傳播的影響 ， 許多回族成爲穆斯林 ， 伊斯蘭教被稱爲回教 。 也因此 ， 在元代之後 ， 由新疆至中國南方 ， 所有穆斯林群體 ， 不分血統 ， 都被稱爲回族 ， 回族因此遍佈全中國 。 相較於今日行政區 ， 其範圍大致包括陝西村 、 金興村 。 陝西是臺灣彰化縣秀水鄉的一個傳統地域名稱 ， 位於該鄉東南部 。 在中華人民共和國之外 ， 尚有中亞東干族與緬甸潘泰人 ， 皆屬於回族 。 至中華人民共和國成立後 ， 回族成爲官方認定的十個信仰伊斯蘭教的少數民族之一 ， 其族群則限縮爲通用漢語 ， 居住在中國內地各省份的居民 ， 與維吾爾族 ， 保安族等分開 。 中華民國成立時 ， 將回族認定爲中國五大民族之一 ， 雖已經有區分出在新疆的維吾爾族與居住在中國其他地區的回民 ， 但其共同特徵仍爲信仰伊斯蘭教 。']

# %%
### Make Piece of XGBoost data

Prepare_XGBoost_Data(test_df)

test_df.head()
###
# Out:
#      id                                claim          predicted_pages  \
# 0  5208  光學顯微鏡是以電磁學原理來將不可見或難見的微小物放大至肉眼可見的儀器。        [顯微鏡, 電磁學, 光學顯微鏡]
# 1  1019              產絲的蠶或產蜜的蜜蜂爲提供間接經濟利益的昆蟲。                     [昆蟲]
# 2  8514              波蘭西部的綠山城縣平均每平方公里的土地有0人。       [綠山城縣, 綠山城, 0, 波蘭]
# 3  1874             Vivien Leigh主演魂斷藍橋中的女配角。   [藍橋_(阿姆斯特丹), 藍橋, 魂斷藍橋]
# 4  8352          侯孝賢改編自唐代文言文學的電影獲得金馬獎最佳劇情片獎。  [文言文, 侯孝賢, 金馬獎, 文學, 電影]
#
#                                   predicted_evidence  \
# 0  [[顯微鏡, 0], [光學顯微鏡, 0], [光學顯微鏡, 9], [光學顯微鏡, 22]...
# 1  [[昆蟲, 22], [昆蟲, 23], [昆蟲, 25], [昆蟲, 15], [昆蟲, ...
# 2  [[綠山城, 0], [綠山城縣, 0], [波蘭, 1], [綠山城, 7], [0, 2...
# 3  [[魂斷藍橋, 0], [藍橋, 2], [魂斷藍橋, 7], [魂斷藍橋, 4], [藍橋...
# 4  [[侯孝賢, 2], [侯孝賢, 1], [侯孝賢, 3], [侯孝賢, 0], [金馬獎,...
#
#                                        evidence_list  \
# 0  顯微鏡泛指將微小不可見或難見物品之影像放大 ， 而能被肉眼或其他成像儀器觀察之工具 。 光學...
# 1  許多昆蟲被認爲是對生態有益的捕食者 ， 少數昆蟲提供直接的經濟利益 。 蠶產絲 ， 蜜蜂產蜂...
# 2  綠山城 （ 波蘭語 ： ； 德語 ： ， 西里西亞的格呂恩貝格 ） 是位於波蘭西部的城市 ，...
# 3  《 魂斷藍橋 》 （ Waterloo Bridge ） 是美國黑白電影 ， 由米高梅電影公...
# 4  2015年以 《 刺客聶隱娘 》 獲得第68屆坎城影展最佳導演獎及第52屆金馬獎最佳導演獎與...
#
#                                              concate
# 0  [CLS] 光學顯微鏡是以電磁學原理來將不可見或難見的微小物放大至肉眼可見的儀器。 [SEP...
# 1  [CLS] 產絲的蠶或產蜜的蜜蜂爲提供間接經濟利益的昆蟲。 [SEP] 許多昆蟲被認爲是對生...
# 2  [CLS] 波蘭西部的綠山城縣平均每平方公里的土地有0人。 [SEP] 綠山城 （ 波蘭語 ...
# 3  [CLS] Vivien Leigh主演魂斷藍橋中的女配角。 [SEP] 《 魂斷藍橋 》 ...
# 4  [CLS] 侯孝賢改編自唐代文言文學的電影獲得金馬獎最佳劇情片獎。 [SEP] 2015年以...

# %%
### Make Piece of XGBoost data

new_df=test_df.iloc[:].reset_index(drop=True)


X_test=Go_Through_SBERT_test(test_df)
print(X_test.shape)
Sbert_df=pd.DataFrame(X_test)

print(X_test[0,:10])

###
# Out:
# Downloading (…)5ee55/.gitattributes:   0%|          | 0.00/445 [00:00<?, ?B/s]
# Downloading (…)92f8d5ee55/README.md:   0%|          | 0.00/1.85k [00:00<?, ?B/s]
# Downloading (…)f8d5ee55/config.json:   0%|          | 0.00/624 [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/412M [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/412M [00:00<?, ?B/s]
# Downloading (…)5ee55/tokenizer.json:   0%|          | 0.00/269k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading (…)92f8d5ee55/vocab.txt:   0%|          | 0.00/110k [00:00<?, ?B/s]
# WARNING:sentence_transformers.SentenceTransformer:No sentence-transformers model found with name /root/.cache/torch/sentence_transformers/bert-base-chinese. Creating a new one with MEAN pooling.
# Some weights of the model checkpoint at /root/.cache/torch/sentence_transformers/bert-base-chinese were not used when initializing BertModel: ['cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# (989, 768)
# [ 0.08124924 -0.1883516  -0.8364163  -0.131873   -0.21483803 -0.04909132
#  -0.16475897  0.24829525 -0.38602337  0.05315962]

# %%
### Make Piece of XGBoost data

Sbert_df.to_csv("Part_3_testing_3_x_data1.csv")

###

# %%
proba = xgboostModel.predict_proba(X_test)
print(proba.shape)
# Out:
# (989, 3)

# %%
print(proba[:10,:])
# Out:
# [[0.00545639 0.17584051 0.8187031 ]
#  [0.00356713 0.35975894 0.6366739 ]
#  [0.00378183 0.10663893 0.8895793 ]
#  [0.00394283 0.31672496 0.6793322 ]
#  [0.00357545 0.14757225 0.8488523 ]
#  [0.00362581 0.28736493 0.70900923]
#  [0.00332588 0.18566038 0.81101376]
#  [0.003372   0.0887337  0.90789425]
#  [0.00321275 0.3016845  0.6951027 ]
#  [0.00313879 0.1214557  0.8754055 ]]
